# %%
#Constructor :

# %%
#1. What is a constructor in Python? Explain its purpose and usage.
'''
In Python, a constructor is a special method within a class that is automatically called 
when an object of the class is created. The purpose of a constructor is to 
initialize the attributes or properties of an object. 
It allows you to set up the initial state of the object when it is instantiated.'''

class MyClass:
    def __init__(self, attribute1, attribute2):
        self.attribute1 = attribute1
        self.attribute2 = attribute2

obj = MyClass('value1', 'value2')
obj.attribute1
# Out:
# 'value1'

# %%
#2. Differentiate between a parameterless constructor and a parameterized constructor in Python.

'''the key difference between a parameterless constructor and a parameterized
constructor is whether or not they accept parameters. Parameterless constructors
don't take any additional parameters, whereas parameterized constructors do, 
allowing you to customize the initialization of the object by passing values during instantiation.'''

class ParameterlessConstructorExample:
    def __init__(self):
        # Default initialization
        self.attribute1 = "Default value 1"
        self.attribute2 = "Default value 2"
        
class ParameterizedConstructorExample:
    def __init__(self, value1, value2):
        # Initializing attributes with values provided as parameters
        self.attribute1 = value1
        self.attribute2 = value2

# Creating an instance with a parameterized constructor
obj = ParameterizedConstructorExample("Custom value 1", "Custom value 2")
obj.attribute2
# Out:
# 'Custom value 2'

# %%
#3. How do you define a constructor in a Python class? Provide an example.
class MyClass:
    def __init__(self, attribute1, attribute2):
        self.attribute1 = attribute1
        self.attribute2 = attribute2

# Creating an instance of MyClass and calling the constructor
obj = MyClass("Value 1", "Value 2")

print(obj.attribute1)  # Output: Value 1
print(obj.attribute2)  # Output: Value 2
# Out:
# Value 1
# Value 2

# %%
#4. Explain the `__init__` method in Python and its role in constructors.
'''In Python, the __init__ method is a special method used in class definitions. 
It plays a crucial role in the concept of constructors. The name __init__ is reserved, 
and this method is automatically called when an object is created from a class.
'''

class MyClass:
    def __init__(self, attribute1, attribute2):
        self.attribute1 = attribute1
        self.attribute2 = attribute2

# Creating an instance of MyClass and calling the constructor
obj = MyClass("Value 1", "Value 2")

# Accessing attributes of the object
print(obj.attribute1)  # Output: Value 1
print(obj.attribute2)  # Output: Value 2
# Out:
# Value 1
# Value 2

# %%
#5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an example of creating an object of this class.
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Creating an instance of the Person class with the constructor
person1 = Person(name="John Doe", age=25)

# Accessing attributes of the person object
print(f"Name: {person1.name}")
print(f"Age: {person1.age}")
# Out:
# Name: John Doe
# Age: 25

# %%
#6. How can you call a constructor explicitly in Python? Give an example.
class MyClass:
    def __init__(self, value):
        self.value = value

    def explicit_constructor_call(self, new_value):
        # Explicitly calling the constructor
        self.__init__(new_value)

# Creating an instance of MyClass
obj = MyClass(value="Original Value")

# Accessing the attribute before explicit constructor call
print(obj.value)  # Output: Original Value

# Explicitly calling the constructor method
obj.explicit_constructor_call(new_value="New Value")

# Accessing the attribute after explicit constructor call
print(obj.value)  # Output: New Value
# Out:
# Original Value
# New Value

# %%
#7. What is the significance of the `self` parameter in Python constructors? Explain with an example.
class MyClass:
    def __init__(self, attribute1, attribute2):
        # Using self to initialize instance variables
        self.attribute1 = attribute1
        self.attribute2 = attribute2

    def display_attributes(self):
        # Accessing instance variables using self
        print(f"Attribute 1: {self.attribute1}")
        print(f"Attribute 2: {self.attribute2}")

# Creating an instance of MyClass
obj = MyClass(attribute1="Value 1", attribute2="Value 2")

# Accessing and displaying attributes using a class method
obj.display_attributes()
# Out:
# Attribute 1: Value 1
# Attribute 2: Value 2

# %%
#8. Discuss the concept of default constructors in Python. When are they used?
'''In Python, a default constructor refers to a constructor that is automatically provided 
by the language if a class definition doesn't explicitly include one.
This default constructor takes no parameters other than the instance reference (self). 
It is automatically called when an object of the class is created.
'''

class MyClassWithoutConstructor:
    pass

# Creating an instance of MyClassWithoutConstructor
obj = MyClassWithoutConstructor()

# The default constructor is called automatically

# %%
#9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height` attributes. 
#Provide a method to calculate the area of the rectangle.
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def calculate_area(self):
        return self.width * self.height

# Creating an instance of the Rectangle class
rectangle1 = Rectangle(width=5, height=8)

# Calculating and printing the area of the rectangle
area = rectangle1.calculate_area()
print(f"Area of the rectangle: {area} square units")
# Out:
# Area of the rectangle: 40 square units

# %%
#10. How can you have multiple constructors in a Python class? Explain with an example.
class MyClass:
    def __init__(self, value1, value2):
        self.value1 = value1
        self.value2 = value2

    @classmethod
    def from_string(cls, input_string):
        # Parsing input string and extracting values
        values = input_string.split(',')
        return cls(value1=values[0], value2=values[1])

    @classmethod
    def default_constructor(cls):
        # Providing default values for the constructor
        return cls(value1='Default 1', value2='Default 2')

# Creating instances using different constructors
obj1 = MyClass(value1='One', value2='Two')
obj2 = MyClass.from_string("Hello,World")
obj3 = MyClass.default_constructor()

# Printing values of the attributes
print(obj1.value1, obj1.value2)  # Output: One Two
print(obj2.value1, obj2.value2)  # Output: Hello
print(obj3.value1, obj3.value2)  # Output: Default 1 Default 2
# Out:
# One Two
# Hello World
# Default 1 Default 2

# %%
#11. What is method overloading, and how is it related to constructors in Python?
class MyClass:
    def __init__(self, value1, value2=0):
        self.value1 = value1
        self.value2 = value2

# Creating instances using different constructors
obj1 = MyClass(value1=10)
obj2 = MyClass(value1=20, value2=30)

print(obj1.value1, obj1.value2)  # Output: 10 0
print(obj2.value1, obj2.value2)  # Output: 20 30
# Out:
# 10 0
# 20 30

# %%
#12. Explain the use of the `super()` function in Python constructors. Provide an example.
class ParentClass:
    def __init__(self, parent_attribute):
        self.parent_attribute = parent_attribute
        print("ParentClass constructor called.")

class ChildClass(ParentClass):
    def __init__(self, parent_attribute, child_attribute):
        # Calling the constructor of the parent class using super()
        super().__init__(parent_attribute)
        
        # Initializing attributes specific to the child class
        self.child_attribute = child_attribute
        print("ChildClass constructor called.")

# Creating an instance of the ChildClass
child_obj = ChildClass(parent_attribute="Parent Value", child_attribute="Child Value")
# Out:
# ParentClass constructor called.
# ChildClass constructor called.

# %%
#13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year` attributes. Provide a method to display book details.
class Book:
    def __init__(self, title, author, published_year):
        self.title = title
        self.author = author
        self.published_year = published_year

    def display_details(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Published Year: {self.published_year}")

# Creating an instance of the Book class
book1 = Book(title="Python Programming", author="John Doe", published_year=2022)

# Displaying details of the book
book1.display_details()
# Out:
# Title: Python Programming
# Author: John Doe
# Published Year: 2022

# %%
#14. Discuss the differences between constructors and regular methods in Python classes.
'''Constructor: The primary purpose of a constructor is to initialize the attributes or properties of an 
object when it is created. It is automatically called upon object instantiation.
Regular Method: Regular methods perform specific actions or operations on the object's data. 
They can be called explicitly on an object, and they may or may not return a value.
'''
class MyClass:
    def __init__(self, attribute):
        self.attribute = attribute

    def regular_method(self):
        return f"Regular method called. Attribute value: {self.attribute}"

# Creating an instance of MyClass
obj = MyClass(attribute="Value")

# Constructor is automatically invoked during object creation
print(obj.attribute)  # Output: Value

# Calling the regular method explicitly
result = obj.regular_method()
print(result)  # Output: Regular method called. Attribute value: Value
# Out:
# Value
# Regular method called. Attribute value: Value

# %%
#15. Explain the role of the `self` parameter in instance variable initialization within a constructor.
'''The self parameter in Python plays a crucial role in instance variable initialization within a constructor. 
In the context of a class method, including the constructor (__init__), self refers to the instance 
of the class that is being created or operated on. 
It allows you to access and manipulate the attributes of the instance.'''

class MyClass:
    def __init__(self, attribute1, attribute2):
        # Using self to initialize instance variables
        self.attribute1 = attribute1
        self.attribute2 = attribute2

    def display_attributes(self):
        # Accessing instance variables using self
        print(f"Attribute 1: {self.attribute1}")
        print(f"Attribute 2: {self.attribute2}")

# Creating an instance of MyClass
obj = MyClass(attribute1="Value 1", attribute2="Value 2")

# Accessing and displaying instance variables using a method
obj.display_attributes()
# Out:
# Attribute 1: Value 1
# Attribute 2: Value 2

# %%
#16. How do you prevent a class from having multiple instances by using constructors in Python? Provide an example.
class SingletonClass:
    # Class variable to store the single instance
    _instance = None

    def __new__(cls, *args, **kwargs):
        # Check if an instance already exists
        if cls._instance is None:
            # Create a new instance if none exists
            cls._instance = super(SingletonClass, cls).__new__(cls)
        # Return the existing instance if one already exists
        return cls._instance

    def __init__(self, data):
        # Initialization logic (called only if a new instance is created)
        if not hasattr(self, '_initialized'):
            self.data = data
            self._initialized = True

# Creating instances of the SingletonClass
singleton_instance1 = SingletonClass(data="Instance 1 Data")
singleton_instance2 = SingletonClass(data="Instance 2 Data")

# Checking if both instances refer to the same object
print(singleton_instance1 is singleton_instance2)  # Output: True

# Accessing data attribute of the singleton instance
print(singleton_instance1.data)  # Output: Instance 1 Data
print(singleton_instance2.data)  # Output: Instance 1 Data
# Out:
# True
# Instance 1 Data
# Instance 1 Data

# %%
#17. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and initializes the `subjects` attribute.
class Student:
    def __init__(self, subjects):
        self.subjects = subjects

    def display_subjects(self):
        print("List of Subjects:")
        for subject in self.subjects:
            print(subject)

# Example usage:
# Creating an instance of the Student class with a list of subjects
student1 = Student(subjects=["Mathematics", "Science", "English"])

# Displaying the subjects using the display_subjects method
student1.display_subjects()
# Out:
# List of Subjects:
# Mathematics
# Science
# English

# %%
#18. What is the purpose of the `__del__` method in Python classes, and how does it relate to constructors?
'''The __del__ method in Python is a special method, also known as a destructor. 
It is called when an object is about to be destroyed or deleted. The primary purpose of
the __del__ method is to perform cleanup actions before the object is removed from memory.'''

class MyClass:
    def __init__(self, name):
        self.name = name
        print(f"{self.name} created.")

    def __del__(self):
        print(f"{self.name} is being destroyed.")

# Creating instances of MyClass
obj1 = MyClass(name="Object 1")
obj2 = MyClass(name="Object 2")

# Deleting references to objects (triggering __del__ method)
del obj1
del obj2
# Out:
# Object 1 created.
# Object 2 created.
# Object 1 is being destroyed.
# Object 2 is being destroyed.

# %%
#19. Explain the use of constructor chaining in Python. Provide a practical example.
class MyClass:
    def __init__(self, value1, value2=None):
        self.value1 = value1
        self.value2 = value2 if value2 is not None else "Default"

    def display_values(self):
        print(f"Value 1: {self.value1}")
        print(f"Value 2: {self.value2}")

# Creating instances using different constructors
obj1 = MyClass(value1="First", value2="Second")
obj2 = MyClass(value1="Only Value")

# Displaying values of the objects
obj1.display_values()
print("----")
obj2.display_values()
# Out:
# Value 1: First
# Value 2: Second
# ----
# Value 1: Only Value
# Value 2: Default

# %%
#20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model` attributes. Provide a method to display car information.
class Car:
    def __init__(self, make="Unknown Make", model="Unknown Model"):
        self.make = make
        self.model = model

    def display_info(self):
        print(f"Car Make: {self.make}")
        print(f"Car Model: {self.model}")

# Creating an instance of the Car class using the default constructor
car1 = Car()

# Displaying car information using the display_info method
car1.display_info()
# Out:
# Car Make: Unknown Make
# Car Model: Unknown Model

# %%
#Inheritance ➖

# %%
#1. What is inheritance in Python? Explain its significance in object-oriented programming.
'''Inheritance is a fundamental concept in object-oriented programming (OOP) 
that allows a class (known as the subclass or derived class) to inherit properties 
and behaviors from another class (known as the superclass or base class). 
The subclass can reuse and extend the functionality of the superclass, 
promoting code reuse and creating a hierarchical relationship between classes.
'''
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        pass  # Placeholder method

class Dog(Animal):
    def speak(self):
        return f"{self.name} says Woof!"

class Cat(Animal):
    def speak(self):
        return f"{self.name} says Meow!"

# Creating instances of the subclasses
dog = Dog(name="Buddy")
cat = Cat(name="Whiskers")

# Using the inherited method
print(dog.speak())  # Output: Buddy says Woof!
print(cat.speak())  # Output: Whiskers says Meow!
# Out:
# Buddy says Woof!
# Whiskers says Meow!

# %%
#2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each.
'''In single inheritance, a class inherits from only one superclass. 
This is a straightforward and common form of inheritance. (refer #1 code )

In multiple inheritance, a class can inherit from more than one superclass. 
This allows the subclass to inherit attributes and methods from multiple classes. 
'''
class Animal:
    def speak(self):
        return "Animal speaks"

class Mammal:
    def milk(self):
        return "Mammal produces milk"

class Dog(Animal, Mammal):
    def bark(self):
        return "Dog barks"

# Creating an instance of the Dog class
dog_instance = Dog()

# Accessing methods from both superclasses and the subclass
print(dog_instance.speak())  # Output: Animal speaks
print(dog_instance.milk())   # Output: Mammal produces milk
print(dog_instance.bark())   # Output: Dog barks
# Out:
# Animal speaks
# Mammal produces milk
# Dog barks

# %%
#3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called `Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object.
class Vehicle:
    def __init__(self, color, speed):
        self.color = color
        self.speed = speed

class Car(Vehicle):
    def __init__(self, color, speed, brand):
        # Call the constructor of the parent class (Vehicle)
        super().__init__(color, speed)
        # Add the brand attribute specific to the Car class
        self.brand = brand

# Example of creating a Car object
car_instance = Car(color="Blue", speed=60, brand="Toyota")

# Accessing attributes of the Car object
print(f"Color: {car_instance.color}")
print(f"Speed: {car_instance.speed}")
print(f"Brand: {car_instance.brand}")
# Out:
# Color: Blue
# Speed: 60
# Brand: Toyota

# %%
#4. Explain the concept of method overriding in inheritance. Provide a practical example.
'''Method overriding in inheritance refers to the ability of a subclass to provide a 
specific implementation for a method that is already defined in its superclass. 
When a method is overridden, the version of the method in the subclass takes
precedence over the version in the superclass. 
This allows the subclass to customize or extend the behavior of the inherited method.'''

class Animal:
    def speak(self):
        return "Animal speaks"

class Dog(Animal):
    def speak(self):
        # Override the speak method in the superclass
        return "Dog barks"

class Cat(Animal):
    def speak(self):
        # Override the speak method in the superclass
        return "Cat meows"

# Creating instances of the subclasses
dog_instance = Dog()
cat_instance = Cat()

# Accessing the overridden speak method
print(dog_instance.speak())  # Output: Dog barks
print(cat_instance.speak())  # Output: Cat meows
# Out:
# Dog barks
# Cat meows

# %%
#5. How can you access the methods and attributes of a parent class from a child class in Python? Give an example.
'''in Python, you can access the methods and attributes of a parent class from a 
child class using the super() function. The super() function returns a temporary object of the superclass,
which allows you to call its methods and access its attributes'''
class Parent:
    def __init__(self, name):
        self.name = name

    def display_info(self):
        return f"Parent class: {self.name}"

class Child(Parent):
    def __init__(self, name, additional_info):
        # Call the constructor of the parent class using super()
        super().__init__(name)
        # Add an additional attribute specific to the Child class
        self.additional_info = additional_info

    def display_info(self):
        # Call the overridden method of the parent class using super()
        parent_info = super().display_info()
        return f"Child class: {self.additional_info}, {parent_info}"

# Example of creating an instance of the Child class
child_instance = Child(name="John", additional_info="Age: 25")

# Accessing attributes and methods of the Child class
print(child_instance.display_info())
print(f"Child name: {child_instance.name}")
print(f"Child additional info: {child_instance.additional_info}")
# Out:
# Child class: Age: 25, Parent class: John
# Child name: John
# Child additional info: Age: 25

# %%
#6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an example.
'''The super() function in Python is used in the context of inheritance to refer to the parent class or superclass. 
It is primarily used to call methods and access attributes of the superclass from the subclass.'''
class Animal:
    def __init__(self, species):
        self.species = species

    def display_info(self):
        return f"I am a {self.species}"

class Mammal(Animal):
    def __init__(self, species, sound):
        # Call the constructor of the superclass using super()
        super().__init__(species)
        self.sound = sound

    def display_info(self):
        # Call the overridden method of the superclass using super()
        return f"{super().display_info()} and I make the sound: {self.sound}"

# Example of creating an instance of the subclass
mammal_instance = Mammal(species="Dog", sound="Woof")

# Accessing methods and attributes using the subclass instance
print(mammal_instance.display_info())
print(f"Species: {mammal_instance.species}")
print(f"Sound: {mammal_instance.sound}")
# Out:
# I am a Dog and I make the sound: Woof
# Species: Dog
# Sound: Woof

# %%
#7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat` that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes.
class Animal:
    def speak(self):
        return "Animal speaks"

class Dog(Animal):
    def speak(self):
        return "Dog barks"

class Cat(Animal):
    def speak(self):
        return "Cat meows"

# Example of using the classes
dog_instance = Dog()
cat_instance = Cat()

# Accessing the overridden speak method
print(dog_instance.speak())  # Output: Dog barks
print(cat_instance.speak())  # Output: Cat meows
# Out:
# Dog barks
# Cat meows

# %%
#8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance.
'''The isinstance() function in Python is used to check if an object belongs to a specified class or 
is an instance of a specified class or a tuple of classes. It returns True if the object is an 
instance of the specified class or any class in the specified tuple, and False otherwise.'''

class Animal:
    pass

class Dog(Animal):
    pass
class Bird(Animal):
    pass
dog_instance = Dog()

print(isinstance(dog_instance, Dog))    # Output: True
print(isinstance(dog_instance, Animal)) # Output: True
print(isinstance(dog_instance, Bird)) # Output: False
# Out:
# True
# True
# False

# %%
#9. What is the purpose of the `issubclass()` function in Python? Provide an example.
'''The issubclass() function in Python is used to check whether a class is a 
subclass of another class. It returns True if the class is a subclass, and False otherwise. 
This function is particularly useful when you want to check the inheritance relationship between classes.'''
class Animal:
    pass

class Mammal(Animal):
    pass

class Dog(Mammal):
    pass

# Checking if Dog is a subclass of Mammal
print(issubclass(Dog, Mammal))  # Output: True

# Checking if Mammal is a subclass of Animal
print(issubclass(Mammal, Animal))  # Output: True

# Checking if Dog is a subclass of Animal
print(issubclass(Dog, Animal))  # Output: True

# Checking if Animal is a subclass of Dog (should be False)
print(issubclass(Animal, Dog))  # Output: False
# Out:
# True
# True
# True
# False

# %%
#10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?
'''In Python, constructor inheritance refers to the way in which child classes
inherit or override the constructors of their parent classes. When a child 
class is created, it can either use the constructor of the parent class (superclass) as is, 
or it can override the constructor with its own implementation. The super() 
function is commonly used to invoke the 
constructor of the parent class within the constructor of the child class.'''

class Parent:
    def __init__(self, name):
        self.name = name

class Child(Parent):
    def __init__(self, name, age):
        # Call the constructor of the parent class using super()
        super().__init__(name)
        self.age = age

# Creating an instance of the child class
child_instance = Child(name="John", age=25)

# Accessing attributes initialized by both parent and child class constructors
print(child_instance.name)  # Output: John
print(child_instance.age)   # Output: 25
# Out:
# John
# 25

# %%
#11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method accordingly. Provide an example.
import math

class Shape:
    def area(self):
        # This method is intended to be overridden by subclasses
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        # Calculate the area of a circle using the formula: π * r^2
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        # Calculate the area of a rectangle using the formula: length * width
        return self.length * self.width

# Example of using the classes
circle_instance = Circle(radius=5)
rectangle_instance = Rectangle(length=4, width=6)

# Calculating and displaying the area of the shapes
print(f"Area of the circle: {circle_instance.area():.2f}")
print(f"Area of the rectangle: {rectangle_instance.area()}")
# Out:
# Area of the circle: 78.54
# Area of the rectangle: 24

# %%
#12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the `abc` module.
'''Abstract Base Classes (ABCs) in Python are classes that cannot be instantiated on their own but
serve as a blueprint for other classes. They often define a set of methods that must be 
implemented by the concrete (derived) classes. ABCs help enforce a 
certain structure or interface in the subclasses, making the code more reliable and maintainable.'''

from abc import ABC, abstractmethod

# Define an abstract base class (ABC)
class Shape(ABC):
    @abstractmethod
    def area(self):
        # This method must be implemented by concrete subclasses
        pass

    @abstractmethod
    def perimeter(self):
        # This method must be implemented by concrete subclasses
        pass

# Concrete subclass Circle that inherits from Shape
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

    def perimeter(self):
        return 2 * 3.14 * self.radius

# Concrete subclass Rectangle that inherits from Shape
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# Creating instances of the concrete subclasses
circle_instance = Circle(radius=5)
rectangle_instance = Rectangle(length=4, width=6)

# Using the methods provided by the abstract base class
print(f"Area of the circle: {circle_instance.area():.2f}")
print(f"Perimeter of the circle: {circle_instance.perimeter():.2f}")

print(f"Area of the rectangle: {rectangle_instance.area()}")
print(f"Perimeter of the rectangle: {rectangle_instance.perimeter()}")
# Out:
# Area of the circle: 78.50
# Perimeter of the circle: 31.40
# Area of the rectangle: 24
# Perimeter of the rectangle: 20

# %%
#13. How can you prevent a child class from modifying certain attributes or methods inherited from a parent class in Python?
class Parent:
    def __init__(self):
        self._protected_attribute = "I am protected"

    def _protected_method(self):
        print("This is a protected method")

class Child(Parent):
    def access_protected(self):
        print(self._protected_attribute)
        self._protected_method()

child_instance = Child()

# Accessing protected attribute and method within the child class
child_instance.access_protected()

class Parent:
    def __init__(self):
        self.__private_attribute = "I am private"

    def __private_method(self):
        print("This is a private method")

class Child(Parent):
    def access_private(self):
        # Accessing private attribute and method using name mangling
        print(self._Parent__private_attribute)
        self._Parent__private_method()

child_instance = Child()

# Accessing private attribute and method within the child class
child_instance.access_private()
# Out:
# I am protected
# This is a protected method
# I am private
# This is a private method

# %%
#14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class `Manager` that inherits from `Employee` and adds an attribute `department`. Provide an example.
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display_info(self):
        return f"Name: {self.name}, Salary: {self.salary}"

class Manager(Employee):
    def __init__(self, name, salary, department):
        # Call the constructor of the parent class using super()
        super().__init__(name, salary)
        self.department = department

    def display_info(self):
        # Override the display_info method to include the department
        return f"{super().display_info()}, Department: {self.department}"

# Example of using the classes
employee_instance = Employee(name="John", salary=50000)
manager_instance = Manager(name="Alice", salary=70000, department="Human Resources")

# Displaying information using the display_info method
print(employee_instance.display_info())
print(manager_instance.display_info())
# Out:
# Name: John, Salary: 50000
# Name: Alice, Salary: 70000, Department: Human Resources

# %%
#15. Discuss the concept of method overloading in Python inheritance. How does it differ from method overriding?
class Calculator:
    def add(self, x, y=0, z=0):
        return x + y + z

# Example of using method overloading
calculator_instance = Calculator()

print(calculator_instance.add(2))        # Output: 2
print(calculator_instance.add(2, 3))     # Output: 5
print(calculator_instance.add(2, 3, 4))  # Output: 9
# Out:
# 2
# 5
# 9

# %%
#16. Explain the purpose of the `__init__()` method in Python inheritance and how it is utilized in child classes.
class Animal:
    def __init__(self, species):
        self.species = species

class Dog(Animal):
    def __init__(self, species, breed):
        # Call the constructor of the parent class using super()
        super().__init__(species)
        self.breed = breed

# Example of using the classes
dog_instance = Dog(species="Canine", breed="Golden Retriever")

# Accessing attributes initialized in both parent and child classes
print(dog_instance.species)  # Output: Canine
print(dog_instance.breed)    # Output: Golden Retriever
# Out:
# Canine
# Golden Retriever

# %%
#17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow` that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these classes.
class Bird:
    def fly(self):
        return "Generic bird can fly"

class Eagle(Bird):
    def fly(self):
        return "Eagle soars through the sky"

class Sparrow(Bird):
    def fly(self):
        return "Sparrow flits and chirps in the air"

# Example of using the classes
bird_instance = Bird()
eagle_instance = Eagle()
sparrow_instance = Sparrow()

# Using the fly() method of each class
print(bird_instance.fly())     # Output: Generic bird can fly
print(eagle_instance.fly())    # Output: Eagle soars through the sky
print(sparrow_instance.fly())  # Output: Sparrow flits and chirps in the air
# Out:
# Generic bird can fly
# Eagle soars through the sky
# Sparrow flits and chirps in the air

# %%
#18. What is the "diamond problem" in multiple inheritance, and how does Python address it?
'''The "diamond problem" is a term used in the context of multiple inheritance in
object-oriented programming. It refers to a specific challenge that arises when a 
class inherits from two classes that have a common ancestor. 
This situation forms a diamond-shaped inheritance hierarchy, leading to ambiguity in method resolution.
      A
     / \
    B   C
     \ /
      D
      '''

class A:
    def method(self):
        print("Method in class A")

class B(A):
    def method(self):
        print("Method in class B")

class C(A):
    def method(self):
        print("Method in class C")

class D(B, C):
    pass

# Example of using the classes
instance_d = D()
instance_d.method()
print(D.__mro__)
# Out:
# Method in class B
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %%
#19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.
'''In an "is-a" relationship, one class is said to be a subtype or derived type of another class. It represents 
a relationship where an object of a derived class is also an object of the base class.'''

# "Is-a" relationship example
class Animal:
    def speak(self):
        pass

class Dog(Animal):  # Dog is a type of Animal
    def speak(self):
        return "Woof!"

# Example of using the "is-a" relationship
dog_instance = Dog()
print(dog_instance.speak())  # Output: Woof!

'''In a "has-a" relationship, one class contains an instance of another class, typically as an attribute. 
It represents a relationship where an object of one class has an object of another class as a part or component.'''

# "Has-a" relationship example
class Engine:
    def start(self):
        return "Engine starting..."

class Car:
    def __init__(self):
        self.engine = Engine()  # Car has an Engine

    def start(self):
        return f"Car starting... {self.engine.start()}"

# Example of using the "has-a" relationship
car_instance = Car()
print(car_instance.start())  # Output: Car starting... Engine starting...
# Out:
# Woof!
# Car starting... Engine starting...

# %%
#20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create child classes `Student` and `Professor`, each with their own attributes and methods. Provide an example of using these classes in a university context.
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        return f"Name: {self.name}, Age: {self.age}"

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def display_info(self):
        # Override the display_info method to include student-specific information
        return f"{super().display_info()}, Student ID: {self.student_id}"

    def study(self, subject):
        return f"{self.name} is studying {subject}"

class Professor(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def display_info(self):
        # Override the display_info method to include professor-specific information
        return f"{super().display_info()}, Employee ID: {self.employee_id}"

    def teach(self, subject):
        return f"{self.name} is teaching {subject}"

# Example of using the classes in a university context
student_instance = Student(name="Alice", age=20, student_id="S12345")
professor_instance = Professor(name="Dr. Smith", age=45, employee_id="P98765")

# Displaying information using the display_info method
print(student_instance.display_info())
print(student_instance.study("Computer Science"))


print(professor_instance.display_info())
print(professor_instance.teach("Mathematics"))
# Out:
# Name: Alice, Age: 20, Student ID: S12345
# Alice is studying Computer Science
# Name: Dr. Smith, Age: 45, Employee ID: P98765
# Dr. Smith is teaching Mathematics

# %%
#Encapsulation ➖

# %%
#1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?
'''Encapsulation is one of the fundamental principles of object-oriented programming (OOP) 
and is aimed at bundling the data (attributes) and the methods that operate on the data 
into a single unit known as a class. It involves restricting access to the internal state of 
an object and requiring all interactions to occur through well-defined interfaces (methods).'''

class Example:
    def __init__(self):
        self.__private_attribute = 42

    def get_private_attribute(self):
        return self.__private_attribute

instance = Example()

# Direct access to private attribute would raise an error
#print(instance.__private_attribute)  # Error

# Accessing through a method
print(instance.get_private_attribute())  # Output: 42
# Out:
# 42

# %%
#2. Describe the key principles of encapsulation, including access control and data hiding.
class EncapsulationExample:
    def __init__(self):
        # Private attribute
        self.__private_attribute = 42

        # Protected attribute
        self._protected_attribute = "Hello"

    # Getter for private attribute
    def get_private_attribute(self):
        return self.__private_attribute

    # Setter for private attribute
    def set_private_attribute(self, new_value):
        if new_value > 0:
            self.__private_attribute = new_value
        else:
            print("Value must be greater than 0.")

    # Method with protected attribute
    def use_protected_attribute(self):
        return f"Using protected attribute: {self._protected_attribute}"

# Example of using the EncapsulationExample class
instance = EncapsulationExample()

# Accessing private attribute using getter
print(instance.get_private_attribute())  # Output: 42

# Modifying private attribute using setter
instance.set_private_attribute(100)
print(instance.get_private_attribute()) 
# Accessing protected attribute using a method
print(instance.use_protected_attribute())  # Output: Using protected attribute: Hello
# Out:
# 42
# 100
# Using protected attribute: Hello

# %%
#3. How can you achieve encapsulation in Python classes? Provide an example.
'''Encapsulation in Python classes can be achieved by following these practices:
Using Private Attributes:Prefix attributes with a double underscore (__) to make them private.
Using Protected Attributes:Prefix attributes with a single underscore (_) to indicate that they are protected.
Using Public Attributes:Attributes without underscores are considered public and can be accessed directly.'''

class EncapsulationExample:
    def __init__(self, public_value, protected_value, private_value):
        # Public attribute
        self.public_value = public_value

        # Protected attribute
        self._protected_value = protected_value

        # Private attribute
        self.__private_value = private_value

    # Getter for private attribute
    def get_private_value(self):
        return self.__private_value

    # Setter for private attribute
    def set_private_value(self, new_value):
        if new_value > 0:
            self.__private_value = new_value
        else:
            print("Value must be greater than 0.")

# Example of using the EncapsulationExample class
instance = EncapsulationExample(public_value="Public", protected_value="Protected", private_value=42)

# Accessing public attribute directly
print("Public Value:", instance.public_value)

# Accessing protected attribute directly (not recommended, but possible)
print("Protected Value:", instance._protected_value)

# Accessing private attribute using getter
print("Private Value (before modification):", instance.get_private_value())

# Modifying private attribute using setter
instance.set_private_value(new_value=100)

# Accessing private attribute using getter after modification
print("Private Value (after modification):", instance.get_private_value())
# Out:
# Public Value: Public
# Protected Value: Protected
# Private Value (before modification): 42
# Private Value (after modification): 100

# %%
#4. Discuss the difference between public, private, and protected access modifiers in Python.
class AccessModifiersExample:
    def __init__(self):
        # Public attribute
        self.public_variable = "I am public"

        # Protected attribute
        self._protected_variable = "I am protected"

        # Private attribute
        self.__private_variable = "I am private"

    # Public method
    def public_method(self):
        return "This is a public method"

    # Protected method
    def _protected_method(self):
        return "This is a protected method"

    # Private method
    def __private_method(self):
        return "This is a private method"

# Example of using the AccessModifiersExample class
instance = AccessModifiersExample()

# Accessing public members
print("Public Variable:", instance.public_variable)
print("Public Method:", instance.public_method())

# Accessing protected members
print("Protected Variable:", instance._protected_variable)
print("Protected Method:", instance._protected_method())

# Accessing private members (Note: This would raise an AttributeError)
# Uncommenting the following line will result in an error:

#print("Private Variable:", instance.__private_variable)
# print("Private Method:", instance.__private_method())
# Out:
# Public Variable: I am public
# Public Method: This is a public method
# Protected Variable: I am protected
# Protected Method: This is a protected method

# %%
#5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the name attribute.
class Person:
    def __init__(self, name):
        # Private attribute
        self.__name = name

    # Getter method for the private attribute
    def get_name(self):
        return self.__name

    # Setter method for the private attribute
    def set_name(self, new_name):
        self.__name = new_name

# Example of using the Person class
person_instance = Person(name="John Doe")

# Accessing the private attribute using the getter
print("Original Name:", person_instance.get_name())

# Modifying the private attribute using the setter
person_instance.set_name(new_name="Jane Doe")

# Accessing the private attribute again using the getter
print("Updated Name:", person_instance.get_name())
# Out:
# Original Name: John Doe
# Updated Name: Jane Doe

# %%
#6. Explain the purpose of getter and setter methods in encapsulation. Provide examples.
'''Getter and setter methods in encapsulation serve the purpose of providing controlled access 
to the private attributes of a class. They are used to retrieve (get) and modify (set) the 
values of private attributes, 
allowing for a level of abstraction and encapsulation of the internal state of an object.'''
class Person:
    def __init__(self, name, age):
        # Private attributes
        self.__name = name
        self.__age = age

    # Getter methods
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    # Setter methods
    def set_name(self, new_name):
        if isinstance(new_name, str):
            self.__name = new_name
        else:
            print("Invalid name format.")

    def set_age(self, new_age):
        if isinstance(new_age, int) and new_age > 0:
            self.__age = new_age
        else:
            print("Invalid age value.")

# Example of using getter and setter methods
person_instance = Person(name="John Doe", age=25)

# Using getter methods to access private attributes
print("Original Name:", person_instance.get_name())
print("Original Age:", person_instance.get_age())

# Using setter methods to modify private attributes
person_instance.set_name(new_name="Jane Doe")
person_instance.set_age(new_age=30)

# Using getter methods again to access modified private attributes
print("Updated Name:", person_instance.get_name())
print("Updated Age:", person_instance.get_age())
# Out:
# Original Name: John Doe
# Original Age: 25
# Updated Name: Jane Doe
# Updated Age: 30

# %%
#7. What is name mangling in Python, and how does it affect encapsulation?
'''
Name mangling in Python is a mechanism that adds a prefix to attribute names in a class
to make them less prone to accidental name clashes. This is achieved by prefixing the 
attribute name with a double underscore (__). The purpose of name mangling 
is to make it more challenging to access and modify private attributes from outside the class.'''

class Example:
    def __init__(self):
        # Private attribute with name mangling
        self.__private_attribute = 42

    def get_private_attribute(self):
        return self.__private_attribute

# Example of using name mangling
clss = Example()

# Accessing the private attribute directly (not recommended)
#print("Direct Access:", clss.__private_attribute)  # This would raise an AttributeError

# Accessing the private attribute using the getter method
print("Getter Method:", clss.get_private_attribute())
# Out:
# Getter Method: 42

# %%
#8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`) and account number (`__account_number`). Provide methods for depositing and withdrawing money.
class BankAccount:
    def __init__(self, account_number, initial_balance=0):
        # Private attributes with name mangling
        self.__account_number = account_number
        self.__balance = initial_balance

    def get_balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Invalid deposit amount. Please deposit a positive amount.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Invalid withdrawal amount or insufficient funds.")

# Example of using the BankAccount class
account = BankAccount(account_number="123456789", initial_balance=1000)

# Accessing balance using the getter method
print("Initial Balance:", account.get_balance())

# Depositing money
account.deposit(500)

# Withdrawing money
account.withdraw(200)

# Trying to withdraw more money than the balance
print("Trying to withdraw more money than the balance")
account.withdraw(10000)
# Out:
# Initial Balance: 1000
# Deposited $500. New balance: $1500
# Withdrew $200. New balance: $1300
# Trying to withdraw more money than the balance
# Invalid withdrawal amount or insufficient funds.

# %%
#9. Discuss the advantages of encapsulation in terms of code maintainability and security.
#Code Maintainability:
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def get_details(self):
        return f"{self.year} {self.make} {self.model}"

# Usage:
my_car = Car(make="Toyota", model="Camry", year=2022)
print(my_car.get_details())

#Flexibility and Extensibility:
class Animal:
    def __init__(self, species):
        self.species = species

    def make_sound(self):
        pass  # Abstract method
class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

#Controlled Access:
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.__account_number = account_number
        self.__balance = balance

    def get_balance(self):
        return self.__balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
# Out:
# 2022 Toyota Camry

# %%
#10. How can you access private attributes in Python? Provide an example demonstrating the use of name mangling.
class MyClass:
    def __init__(self):
        # Private attribute with name mangling
        self.__private_attribute = 42

# Creating an instance of MyClass
obj = MyClass()

# Attempting to access the private attribute directly (discouraged)
# This would normally raise an AttributeError, but we can use name mangling
print(obj._MyClass__private_attribute)
# Out:
# 42

# %%
#11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses, and implement encapsulation principles to protect sensitive information.
class Person:
    def __init__(self, name, age):
        self._name = name  # Protected attribute
        self._age = age    # Protected attribute

    def get_name(self):
        return self._name

    def get_age(self):
        return self._age


class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.__student_id = student_id  # Private attribute
        self.__grades = {}             # Private attribute

    def get_student_id(self):
        return self.__student_id

    def add_grade(self, course, grade):
        # Private method to add grades
        self.__grades[course] = grade

    def get_grades(self):
        return self.__grades.copy()  # Return a copy to avoid direct modification


class Teacher(Person):
    def __init__(self, name, age, employee_id, salary):
        super().__init__(name, age)
        self.__employee_id = employee_id  # Private attribute
        self.__salary = salary            # Private attribute
        self.__courses_taught = []        # Private attribute

    def get_employee_id(self):
        return self.__employee_id

    def get_salary(self):
        return self.__salary

    def add_course_taught(self, course):
        # Private method to add courses taught
        self.__courses_taught.append(course)

    def get_courses_taught(self):
        return self.__courses_taught.copy()  # Return a copy to avoid direct modification


class Course:
    def __init__(self, course_code, course_name):
        self._course_code = course_code  # Protected attribute
        self._course_name = course_name  # Protected attribute
        self.__students_enrolled = []    # Private attribute

    def get_course_code(self):
        return self._course_code

    def get_course_name(self):
        return self._course_name

    def enroll_student(self, student):
        # Private method to enroll students
        self.__students_enrolled.append(student)

    def get_students_enrolled(self):
        return self.__students_enrolled.copy()  # Return a copy to avoid direct modification


# Example of using the school system classes
# Example of using the school system classes
student1 = Student(name="Alice", age=16, student_id="S101")
teacher1 = Teacher(name="Mr. Smith", age=35, employee_id="T201", salary=50000)
course1 = Course(course_code="C101", course_name="Mathematics")

course1.enroll_student(student1)
teacher1.add_course_taught(course1)

# Accessing information using protected and public methods
print(f"{student1.get_name()} (ID: {student1.get_student_id()}) is enrolled in {course1.get_course_name()}.")

# Corrected code to extract course names before joining
teacher1_courses = [course.get_course_name() for course in teacher1.get_courses_taught()]
print(f"{teacher1.get_name()} (ID: {teacher1.get_employee_id()}) is teaching {', '.join(teacher1_courses)}.")
# Out:
# Alice (ID: S101) is enrolled in Mathematics.
# Mr. Smith (ID: T201) is teaching Mathematics.

# %%
#12. Explain the concept of property decorators in Python and how they relate to encapsulation.
#The @property decorator is used to define a method as a getter for an attribute.

class MyClass:
    def __init__(self):
        self._value = 42  # Protected attribute

    @property #for getter
    def my_property(self):
        return self._value

    @my_property.setter #fore setter
    def my_property(self, new_value):
        if new_value > 0:
            self._value = new_value

    @my_property.deleter #for delete
    def my_property(self):
        print("Deleting my_property")
        del self._value

# Usage
obj = MyClass()
print(obj.my_property)  # Calls the getter method

obj.my_property = 50  # Calls the setter method with validation
print(obj.my_property)  # Calls the getter method

del obj.my_property  # Calls the deleter method
# Out:
# 42
# 50
# Deleting my_property

# %%
#13. What is data hiding, and why is it important in encapsulation? Provide examples.
'''Data hiding is a concept in object-oriented programming that refers to restricting access to 
certain details of an object and only exposing what is necessary. It involves encapsulating the 
internal state of an object and making 
it accessible or modifiable only through well-defined interfaces, such as methods or properties.'''

class BankAccount:
    def __init__(self, account_number, balance=0):
        self._account_number = account_number  # Protected attribute
        self.__balance = balance               # Private attribute

    @property
    def account_number(self):
        return self._account_number

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, new_balance):
        if new_balance >= 0:
            self.__balance = new_balance
# Example of using the BankAccount class
account = BankAccount(account_number="123456789")
print(account.balance)  # Accessing the balance property

# Setting a new balance using the setter method with validation
account.balance = 1000
print(account.balance)  # Accessing the updated balance property
# Out:
# 0
# 1000

# %%
#14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`). Provide a method to calculate yearly bonuses.
class Employee:
    def __init__(self, employee_id, salary):
        self.__employee_id = employee_id  # Private attribute
        self.__salary = salary            # Private attribute

    @property
    def employee_id(self):
        return self.__employee_id

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, new_salary):
        if new_salary >= 0:
            self.__salary = new_salary

    def calculate_yearly_bonus(self, bonus_percentage):
        """
        Calculate yearly bonus based on the provided percentage.

        Args:
            bonus_percentage (float): Bonus percentage to be applied.

        Returns:
            float: Calculated yearly bonus.
        """
        if 0 <= bonus_percentage <= 100:
            bonus_amount = (bonus_percentage / 100) * self.__salary
            return bonus_amount
        else:
            raise ValueError("Bonus percentage should be between 0 and 100.")

# Example of using the Employee class
employee1 = Employee(employee_id="E101", salary=50000)
print(f"Employee ID: {employee1.employee_id}")
print(f"Current Salary: ${employee1.salary}")

# Updating salary using the setter method with validation
employee1.salary = 55000
print(f"Updated Salary: ${employee1.salary}")

# Calculating yearly bonus
bonus_percentage = 10
yearly_bonus = employee1.calculate_yearly_bonus(bonus_percentage)
print(f"Yearly Bonus ({bonus_percentage}%): ${yearly_bonus}")
# Out:
# Employee ID: E101
# Current Salary: $50000
# Updated Salary: $55000
# Yearly Bonus (10%): $5500.0

# %%
#15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over attribute access?
#Accessors (Getters):
#Purpose: Accessors, or getters, are methods that retrieve the values of private attributes. They provide a way to get the current state of an object.
#Example:

class MyClass:
    def __init__(self):
        self.__private_attribute = 42

    def get_private_attribute(self):
        return self.__private_attribute
    
#Mutators (Setters):
#Purpose: Mutators, or setters, are methods that modify the values of private attributes. They provide a way to update the state of an object.
#Example:
class MyClass:
    def __init__(self):
        self.__private_attribute = 42

    def set_private_attribute(self, new_value):
        if new_value >= 0:
            self.__private_attribute = new_value

# %%
#16. What are the potential drawbacks or disadvantages of using encapsulation in Python?
'''
Encapsulation in Python may introduce overhead and verbosity, restricts direct access,
has a learning curve, 
and requires maintenance, with a potential trade-off between control and flexibility.'''
#Certainly, let's consider a simple example illustrating encapsulation with accessors and mutators:
class Rectangle:
    def __init__(self, length, width):
        self.__length = length  # Private attribute
        self.__width = width    # Private attribute

    @property
    def length(self):
        return self.__length

    @property
    def width(self):
        return self.__width

    @length.setter
    def length(self, new_length):
        if new_length > 0:
            self.__length = new_length

    @width.setter
    def width(self, new_width):
        if new_width > 0:
            self.__width = new_width

    def calculate_area(self):
        return self.__length * self.__width


# Example of using the Rectangle class
rectangle = Rectangle(length=5, width=3)

# Accessing attributes using accessors
print(f"Length: {rectangle.length}")  # Output: Length: 5
print(f"Width: {rectangle.width}")    # Output: Width: 3

# Modifying attributes using mutators
rectangle.length = 8
rectangle.width = 4

# Calculating area
area = rectangle.calculate_area()
print(f"Area: {area}")  # Output: Area: 32
# Out:
# Length: 5
# Width: 3
# Area: 32

# %%
#17. Create a Python class for a library system that encapsulates book information, including titles, authors, and availability status.
class Book:
    def __init__(self, title, author, available=True):
        self.__title = title        # Private attribute
        self.__author = author      # Private attribute
        self.__available = available  # Private attribute

    @property
    def title(self):
        return self.__title

    @property
    def author(self):
        return self.__author

    @property
    def available(self):
        return self.__available

    @available.setter
    def available(self, status):
        self.__available = status

    def display_info(self):
        status = "available" if self.__available else "not available"
        print(f"Title: {self.__title}, Author: {self.__author}, Status: {status}")


# Example of using the Book class in a library system
book1 = Book(title="The Great Gatsby", author="F. Scott Fitzgerald")
book2 = Book(title="To Kill a Mockingbird", author="Harper Lee", available=False)

# Displaying book information
book1.display_info()
book2.display_info()

# Modifying book availability
book1.available = False

# Displaying updated information
book1.display_info()
# Out:
# Title: The Great Gatsby, Author: F. Scott Fitzgerald, Status: available
# Title: To Kill a Mockingbird, Author: Harper Lee, Status: not available
# Title: The Great Gatsby, Author: F. Scott Fitzgerald, Status: not available

# %%
#18. Explain how encapsulation enhances code reusability and modularity in Python programs.
class Person:
    def __init__(self, name, age):
        self.__name = name      # Encapsulated private attribute
        self.__age = age        # Encapsulated private attribute

    @property
    def name(self):
        return self.__name

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, new_age):
        if 0 <= new_age <= 150:  # Validating age to be within a reasonable range
            self.__age = new_age

    def display_info(self):
        print(f"Name: {self.__name}, Age: {self.__age}")


# Example of using the Person class in a program
person1 = Person(name="Alice", age=30)
person2 = Person(name="Bob", age=25)

# Displaying information using encapsulated getters
print(f"{person1.name} is {person1.age} years old.")
print(f"{person2.name} is {person2.age} years old.")

# Modifying information using encapsulated setters
person1.age = 31
person2.age = 26

# Displaying updated information
person1.display_info()
person2.display_info()
# Out:
# Alice is 30 years old.
# Bob is 25 years old.
# Name: Alice, Age: 31
# Name: Bob, Age: 26

# %%
#19. Describe the concept of information hiding in encapsulation. Why is it essential in software development?
'''Information hiding is a crucial concept in encapsulation that involves restricting access 
to certain details of a class or module,
revealing only what is necessary for the external world to interact with the functionality provided.'''

#BankAccount class where the balance is a private attribute, and users can interact with the account through deposit and withdraw methods:
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Insufficient funds. Withdrawal canceled.")

    def get_balance(self):
        return self.__balance


# Example of using the BankAccount class
account = BankAccount(initial_balance=1000)

# Attempting to access the private attribute directly (not allowed)
# print(account.__balance)  # This would raise an AttributeError

# Accessing the balance through the public method (get_balance)
current_balance = account.get_balance()
print(f"Current balance: ${current_balance}")

# Depositing and withdrawing money
account.deposit(500)
account.withdraw(200)
account.withdraw(1200)  # This will be rejected due to insufficient funds

# Checking the final balance
final_balance = account.get_balance()
print(f"Final balance: ${final_balance}")
# Out:
# Current balance: $1000
# Deposited $500. New balance: $1500
# Withdrew $200. New balance: $1300
# Withdrew $1200. New balance: $100
# Final balance: $100

# %%
#20. Create a Python class called `Customer` with private attributes for customer details like name, address, and contact information. Implement encapsulation to ensure data integrity and security.
class Customer:
    def __init__(self, name, address, contact_info):
        self.__name = name               # Private attribute
        self.__address = address         # Private attribute
        self.__contact_info = contact_info  # Private attribute

    # Getter methods for accessing private attributes
    @property
    def name(self):
        return self.__name

    @property
    def address(self):
        return self.__address

    @property
    def contact_info(self):
        return self.__contact_info

    # Setter methods for modifying private attributes
    @name.setter
    def name(self, new_name):
        if new_name:
            self.__name = new_name

    @address.setter
    def address(self, new_address):
        if new_address:
            self.__address = new_address

    @contact_info.setter
    def contact_info(self, new_contact_info):
        if new_contact_info:
            self.__contact_info = new_contact_info

    def display_info(self):
        print(f"Customer Information:\nName: {self.__name}\nAddress: {self.__address}\nContact: {self.__contact_info}")


# Example of using the Customer class
customer = Customer(name="John Doe", address="123 Main St", contact_info="john@example.com")

# Accessing private attributes using getters
print(f"Customer Name: {customer.name}")
print(f"Customer Address: {customer.address}")
print(f"Customer Contact: {customer.contact_info}")

# Modifying private attributes using setters
customer.name = "Jane Doe"
customer.address = "456 Oak St"
customer.contact_info = "jane@example.com"

# Displaying updated customer information
customer.display_info()
# Out:
# Customer Name: John Doe
# Customer Address: 123 Main St
# Customer Contact: john@example.com
# Customer Information:
# Name: Jane Doe
# Address: 456 Oak St
# Contact: jane@example.com

# %%
#Polymorphism:-

# %%
#1. What is polymorphism in Python? Explain how it is related to object-oriented programming.
#Polymorphism is a fundamental concept in object-oriented programming (OOP) that allows objects of different types to be treated as objects of a common type. 
class MathOperations:
    def add(self, a, b):
        return a + b

    def add_three(self, a, b, c):
        return a + b + c

# Creating an instance of the MathOperations class
math_ops = MathOperations()

# Calling the appropriate method based on the number of arguments
result1 = math_ops.add(2, 3)        # Calls the first add method
result2 = math_ops.add_three(2, 3, 4)     # Calls the second add method

print(result1)  # Output: 5
print(result2)  # Output: 9
# Out:
# 5
# 9
# Woof!
# Meow!

# %%
#2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python.
#Compile-time (Static) Polymorphism:
class MathOperations:
    def add(self, a, b):
        return a + b

    def add_three(self, a, b, c):
        return a + b + c

# Creating an instance of the MathOperations class
math_ops = MathOperations()

# Calling the appropriate method based on the number of arguments
result1 = math_ops.add(2, 3)        # Calls the first add method
result2 = math_ops.add_three(2, 3, 4)     # Calls the second add method

print(result1)  # Output: 5
print(result2)  # Output: 9



#Run-time (Dynamic) Polymorphism:
class Animal:
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

def animal_speak(animal):
    return animal.make_sound()

dog = Dog()
cat = Cat()

print(animal_speak(dog))  # Outputs: Woof!
print(animal_speak(cat))  # Outputs: Meow!

# %%
#3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism through a common method, such as `calculate_area()`.
import math

# Base class for shapes
class Shape:
    def calculate_area(self):
        pass  # This method will be overridden by subclasses

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius ** 2

# Square class
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length ** 2

# Triangle class
class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        return 0.5 * self.base * self.height

# Function to calculate and print the area of a shape
def print_area(shape):
    area = shape.calculate_area()
    print(f"The area of the shape is: {area}")

# Creating instances of different shapes
circle = Circle(radius=5)
square = Square(side_length=4)
triangle = Triangle(base=6, height=3)

# Demonstrating polymorphism by calling the common method on different shapes
print_area(circle)    # Output: The area of the shape is: 78.53981633974483
print_area(square)    # Output: The area of the shape is: 16
print_area(triangle)  # Output: The area of the shape is: 9.0
# Out:
# The area of the shape is: 78.53981633974483
# The area of the shape is: 16
# The area of the shape is: 9.0

# %%
#4. Explain the concept of method overriding in polymorphism. Provide an example.
'''Method overriding is a concept in object-oriented programming where a subclass 
provides a specific implementation for a method that is already defined in its superclass. 
The overridden method in the subclass has 
the same signature (name, return type, and parameters) as the method in the superclass.'''

class Animal:
    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

# Creating instances of the subclasses
dog = Dog()
cat = Cat()

# Calling the overridden method on each object
print(dog.make_sound())  # Output: Woof!
print(cat.make_sound())  # Output: Meow!
# Out:
# Woof!
# Meow!

# %%
#5. How is polymorphism different from method overloading in Python? Provide examples for both.
'''Polymorphism and method overloading are both concepts in object-oriented programming,
but they are different in terms of their implementations and use cases.'''

class Animal:
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

# Polymorphism in action
def animal_sound(animal):
    return animal.make_sound()

dog = Dog()
cat = Cat()

print(animal_sound(dog))  # Output: Woof!
print(animal_sound(cat))  # Output: Meow!
# Out:
# Woof!
# Meow!

# %%
#6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`, each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method on objects of different subclasses.
class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Bird(Animal):
    def speak(self):
        return "Chirp!"

# Creating instances of different subclasses
dog = Dog()
cat = Cat()
bird = Bird()

# Demonstrating polymorphism by calling the common method on different objects
print(dog.speak())  # Output: Woof!
print(cat.speak())  # Output: Meow!
print(bird.speak())  # Output: Chirp!
# Out:
# Woof!
# Meow!
# Chirp!

# %%
#7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example using the `abc` module.
''' abstract methods and classes provide a way to define a common interface for a group of 
related classes, ensuring that each subclass implements specific methods. Abstract classes 
cannot be instantiated, and their abstract methods must be implemented by their concrete subclasses
The abc module in Python provides the ABC (Abstract Base Class) and abstractmethod decorator 
to create abstract classes and abstract methods,respectively.'''
from abc import ABC, abstractmethod

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Concrete subclass 1
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

# Concrete subclass 2
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def area(self):
        return self.side_length ** 2

# Function to calculate and print the area of a shape
def print_area(shape):
    if isinstance(shape, Shape):  # Ensure that the object is an instance of the abstract base class
        area = shape.area()
        print(f"The area of the shape is: {area}")
    else:
        print("Invalid shape object")

# Creating instances of concrete subclasses
circle = Circle(radius=5)
square = Square(side_length=4)

# Demonstrating polymorphism by calling the common method on different shapes
print_area(circle)  # Output: The area of the shape is: 78.5
print_area(square)  # Output: The area of the shape is: 16
# Out:
# The area of the shape is: 78.5
# The area of the shape is: 16

# %%
#8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` method that prints a message specific to each vehicle type.
class Vehicle:
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        return "Car engine started. Vroom!"

class Bicycle(Vehicle):
    def start(self):
        return "Bicycle pedaling started. Ring ring!"

class Boat(Vehicle):
    def start(self):
        return "Boat engine started. Splashing water!"

# Function to start and print the message for any vehicle
def start_vehicle(vehicle):
    if isinstance(vehicle, Vehicle):  # Ensure that the object is an instance of the base class
        message = vehicle.start()
        print(message)
    else:
        print("Invalid vehicle object")

# Creating instances of different vehicle types
car = Car()
bicycle = Bicycle()
boat = Boat()

# Demonstrating polymorphism by calling the common method on different vehicles
start_vehicle(car)      # Output: Car engine started. Vroom!
start_vehicle(bicycle)  # Output: Bicycle pedaling started. Ring ring!
start_vehicle(boat)     # Output: Boat engine started. Splashing water!
# Out:
# Car engine started. Vroom!
# Bicycle pedaling started. Ring ring!
# Boat engine started. Splashing water!

# %%
#9. Explain the significance of the `isinstance()` and `issubclass()` functions in Python polymorphism.
class Animal:
    pass

class Dog(Animal):
    pass

obj = Dog()

if isinstance(obj, Animal):
    print("The object is an instance of Animal or its subclass.")
class Vehicle:
    pass

class Car(Vehicle):
    pass

if issubclass(Car, Vehicle):
    print("Car is a subclass of Vehicle.")
# Out:
# The object is an instance of Animal or its subclass.
# Car is a subclass of Vehicle.

# %%
#10. What is the role of the `@abstractmethod` decorator in achieving polymorphism in Python? Provide an example.
from abc import ABC, abstractmethod

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Concrete subclass 1
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

# Concrete subclass 2
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def area(self):
        return self.side_length ** 2

# Function to calculate and print the area of a shape
def print_area(shape):
    if isinstance(shape, Shape):  # Ensure that the object is an instance of the abstract base class
        area = shape.area()
        print(f"The area of the shape is: {area}")
    else:
        print("Invalid shape object")

# Creating instances of concrete subclasses
circle = Circle(radius=5)
square = Square(side_length=4)

# Demonstrating polymorphism by calling the common method on different shapes
print_area(circle)  # Output: The area of the shape is: 78.5
print_area(square)  # Output: The area of the shape is: 16
# Out:
# The area of the shape is: 78.5
# The area of the shape is: 16

# %%
#11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle).
import math

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

# Function to calculate and print the area of any shape
def print_area(shape):
    if isinstance(shape, Shape):  # Ensure that the object is an instance of the base class
        area = shape.area()
        print(f"The area of the shape is: {area}")
    else:
        print("Invalid shape object")

# Creating instances of different shapes
circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)
triangle = Triangle(base=3, height=8)

# Demonstrating polymorphism by calling the common method on different shapes
print_area(circle)     # Output: The area of the shape is: 78.53981633974483
print_area(rectangle)  # Output: The area of the shape is: 24
print_area(triangle)   # Output: The area of the shape is: 12.0
# Out:
# The area of the shape is: 78.53981633974483
# The area of the shape is: 24
# The area of the shape is: 12.0

# %%
#12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs.
import math

class Shape:
    def draw(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def draw(self):
        print(f"Drawing a circle with radius {self.radius}")

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def draw(self):
        print(f"Drawing a rectangle with width {self.width} and height {self.height}")

# Function to draw any shape without knowing its specific type
def draw_shape(shape):
    if isinstance(shape, Shape):  # Ensure that the object is an instance of the base class
        shape.draw()
    else:
        print("Invalid shape object")

# Creating instances of different shapes
circle = Circle(radius=5)
rectangle = Rectangle(width=4, height=6)

# Demonstrating polymorphism by calling the common method on different shapes
draw_shape(circle)     # Output: Drawing a circle with radius 5
draw_shape(rectangle)  # Output: Drawing a rectangle with width 4 and height 6
# Out:
# Drawing a circle with radius 5
# Drawing a rectangle with width 4 and height 6

# %%
#13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent classes?
class Parent:
    def show_message(self):
        print("Message from Parent")

class Child(Parent):
    def show_message(self):
        super().show_message()  # Call the show_message method of the parent class
        print("Message from Child")

# Creating an instance of the Child class
child_instance = Child()

# Calling the overridden method in the Child class
child_instance.show_message()
# Out:
# Message from Parent
# Message from Child

# %%
#14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking, credit card) and demonstrate polymorphism by implementing a common `withdraw()` method.
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawal of ${amount} successful. Remaining balance: ${self.balance}")
        else:
            print("Invalid withdrawal amount or insufficient funds.")

class SavingsAccount(BankAccount):
    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def apply_interest(self):
        self.balance += self.balance * self.interest_rate
        print(f"Interest applied. New balance: ${self.balance}")

class CheckingAccount(BankAccount):
    def __init__(self, account_number, balance, overdraft_limit):
        super().__init__(account_number, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if amount > 0 and amount <= (self.balance + self.overdraft_limit):
            self.balance -= amount
            print(f"Withdrawal of ${amount} successful. Remaining balance: ${self.balance}")
        else:
            print("Invalid withdrawal amount or overdraft limit reached.")

class CreditCardAccount(BankAccount):
    def __init__(self, account_number, balance, credit_limit):
        super().__init__(account_number, balance)
        self.credit_limit = credit_limit

    def withdraw(self, amount):
        if amount > 0 and amount <= (self.balance + self.credit_limit):
            self.balance -= amount
            print(f"Credit card withdrawal of ${amount} successful. Remaining balance: ${self.balance}")
        else:
            print("Invalid withdrawal amount or credit limit reached.")

# Creating instances of different account types
savings_account = SavingsAccount(account_number="SAV123", balance=1000, interest_rate=0.05)
checking_account = CheckingAccount(account_number="CHK456", balance=1500, overdraft_limit=500)
credit_card_account = CreditCardAccount(account_number="CC789", balance=-200, credit_limit=1000)

# Demonstrating polymorphism by calling the common withdraw method on different account types
savings_account.withdraw(200)          # Output: Withdrawal of $200 successful. Remaining balance: $800
checking_account.withdraw(200)         # Output: Withdrawal of $200 successful. Remaining balance: $1300
credit_card_account.withdraw(200)      # Output: Credit card withdrawal of $200 successful. Remaining balance: $-400
# Out:
# Withdrawal of $200 successful. Remaining balance: $800
# Withdrawal of $200 successful. Remaining balance: $1300
# Credit card withdrawal of $200 successful. Remaining balance: $-400

# %%
#15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide examples using operators like `+` and `*`.
#Operator Overloading for Addition (+)
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other_point):
        if isinstance(other_point, Point):
            return Point(self.x + other_point.x, self.y + other_point.y)
        else:
            raise TypeError("Unsupported operand type. You can only add Point objects.")

# Creating instances of the Point class
point1 = Point(1, 2)
point2 = Point(3, 4)

# Using the overloaded + operator
result_point = point1 + point2
print(f"Resultant Point: ({result_point.x}, {result_point.y})")


#Operator Overloading for Multiplication (*)
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __mul__(self, scalar):
        if isinstance(scalar, (int, float)):
            return Vector(self.x * scalar, self.y * scalar)
        else:
            raise TypeError("Unsupported operand type. You can only multiply Vector by a scalar.")

# Creating an instance of the Vector class
vector = Vector(2, 3)

# Using the overloaded * operator
scaled_vector = vector * 2
print(f"Scaled Vector: ({scaled_vector.x}, {scaled_vector.y})")
# Out:
# Resultant Point: (4, 6)
# Scaled Vector: (4, 6)

# %%
#16. What is dynamic polymorphism, and how is it achieved in Python?
'''Dynamic polymorphism, also known as runtime polymorphism, is a type of polymorphism
that allows objects to be 
treated as instances of their parent class, even when they are instances of a derived class. '''
class Animal:
    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof! Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")

# Function that demonstrates dynamic polymorphism
def animal_sound(animal):
    animal.make_sound()

# Creating instances of different classes
generic_animal = Animal()
dog = Dog()
cat = Cat()

# Calling the function with different objects
animal_sound(generic_animal)  # Output: Generic animal sound
animal_sound(dog)             # Output: Woof! Woof!
animal_sound(cat)             # Output: Meow!
# Out:
# Generic animal sound
# Woof! Woof!
# Meow!

# %%
#17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common `calculate_salary()` method.
class Employee:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def calculate_salary(self):
        # Common salary calculation logic for all employees
        return 50000  # A default salary for illustration purposes

class Manager(Employee):
    def __init__(self, name):
        super().__init__(name, role="Manager")

    def calculate_salary(self):
        # Additional logic for calculating salary for managers
        return super().calculate_salary() + 20000

class Developer(Employee):
    def __init__(self, name):
        super().__init__(name, role="Developer")

    def calculate_salary(self):
        # Additional logic for calculating salary for developers
        return super().calculate_salary() + 10000

class Designer(Employee):
    def __init__(self, name):
        super().__init__(name, role="Designer")

    def calculate_salary(self):
        # Additional logic for calculating salary for designers
        return super().calculate_salary() + 15000

# Function to demonstrate polymorphism
def print_salary(employee):
    print(f"{employee.name}, {employee.role}: Salary - ${employee.calculate_salary()}")

# Creating instances of different employee roles
manager = Manager("Alice")
developer = Developer("Bob")
designer = Designer("Charlie")

# Demonstrating polymorphism by calling the common calculate_salary method on different employee roles
print_salary(manager)    # Output: Alice, Manager: Salary - $70000
print_salary(developer)  # Output: Bob, Developer: Salary - $60000
print_salary(designer)   # Output: Charlie, Designer: Salary - $65000
# Out:
# Alice, Manager: Salary - $70000
# Bob, Developer: Salary - $60000
# Charlie, Designer: Salary - $65000

# %%
#18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.

#Method Overriding:
class Animal:
    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof! Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")

# Function that demonstrates polymorphism
def animal_sound(animal):
    animal.make_sound()

# Creating instances of different classes
generic_animal = Animal()
dog = Dog()
cat = Cat()

# Calling the function with different objects
animal_sound(generic_animal)  # Output: Generic animal sound
animal_sound(dog)             # Output: Woof! Woof!
animal_sound(cat)             # Output: Meow!
# Out:
# Generic animal sound
# Woof! Woof!
# Meow!

# %%
#19. Explain the role of interfaces and abstract classes in polymorphism, drawing comparisons between them.
#Abstract Classes:
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2
    
#Interfaces (Abstract Base Classes without Methods):
class Printable:
    def display(self):
        pass

class Document(Printable):
    def __init__(self, content):
        self.content = content

    def display(self):
        print(self.content)
#Comparisons

# %%
#20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., mammals, birds, reptiles) and their behavior (e.g., eating, sleeping, making sounds).
class Animal:
    def __init__(self, name):
        self.name = name

    def make_sound(self):
        pass

    def eat(self):
        pass

    def sleep(self):
        pass

class Mammal(Animal):
    def give_birth(self):
        pass

class Bird(Animal):
    def fly(self):
        pass

class Reptile(Animal):
    def crawl(self):
        pass

class Lion(Mammal):
    def make_sound(self):
        return "Roar"

    def eat(self):
        return "Lion is eating meat"

    def sleep(self):
        return "Lion is sleeping"

    def give_birth(self):
        return "Lioness gave birth to cubs"

class Eagle(Bird):
    def make_sound(self):
        return "Screech"

    def eat(self):
        return "Eagle is eating fish"

    def sleep(self):
        return "Eagle is perched and sleeping"

    def fly(self):
        return "Eagle is flying high in the sky"

class Snake(Reptile):
    def make_sound(self):
        return "Hiss"

    def eat(self):
        return "Snake is swallowing its prey"

    def sleep(self):
        return "Snake is coiled up and resting"

    def crawl(self):
        return "Snake is slithering on the ground"

# Create instances of different animals
lion = Lion("Simba")
eagle = Eagle("Thunder")
snake = Snake("Slytherin")

# Demonstrate polymorphism
animals = [lion, eagle, snake]

for animal in animals:
    print(f"{animal.name}: {animal.make_sound()}")
    print(f"{animal.name}: {animal.eat()}")
    print(f"{animal.name}: {animal.sleep()}")

    if isinstance(animal, Mammal):
        print(f"{animal.name}: {animal.give_birth()}")
    elif isinstance(animal, Bird):
        print(f"{animal.name}: {animal.fly()}")
    elif isinstance(animal, Reptile):
        print(f"{animal.name}: {animal.crawl()}")

    print("\n")
# Out:
# Simba: Roar
# Simba: Lion is eating meat
# Simba: Lion is sleeping
# Simba: Lioness gave birth to cubs
#
#
# Thunder: Screech
# Thunder: Eagle is eating fish
# Thunder: Eagle is perched and sleeping
# Thunder: Eagle is flying high in the sky
#
#
# Slytherin: Hiss
# Slytherin: Snake is swallowing its prey
# Slytherin: Snake is coiled up and resting
# Slytherin: Snake is slithering on the ground

# %%
#Abstraction:

# %%
#1. What is abstraction in Python, and how does it relate to object-oriented programming?
'''Abstraction is a fundamental concept in object-oriented programming (OOP) that involves simplifying 
complex systems by modeling classes based on the essential properties and behaviors they share. '''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

    def perimeter(self):
        return 2 * 3.14 * self.radius

# %%
#2. Describe the benefits of abstraction in terms of code organization and complexity reduction.
'''
Abstraction offers several benefits in terms of code organization and complexity reduction in software development:
Simplified Modeling:
Code Reusability:
Modularity:
Encapsulation of Complexity:
Ease of Maintenance:
Flexibility and Extensibility:'''

from abc import ABC, abstractmethod

# With abstraction, we define an abstract class for shapes.

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


# Usage with abstraction
circle = Circle(5)
rectangle = Rectangle(4, 6)

def print_shape_info(shape):
    print(f"{shape.__class__.__name__} Area:", shape.calculate_area())
    print(f"{shape.__class__.__name__} Perimeter:", shape.calculate_perimeter())
    print()

print_shape_info(circle)
print_shape_info(rectangle)
# Out:
# Circle Area: 78.5
# Circle Perimeter: 31.400000000000002
#
# Rectangle Area: 24
# Rectangle Perimeter: 20

# %%
#3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of using these classes.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Example usage
circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)

# Calculate and print areas
print(f"Circle Area: {circle.calculate_area()}")
print(f"Rectangle Area: {rectangle.calculate_area()}")
# Out:
# Circle Area: 78.5
# Rectangle Area: 24

# %%
#4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide an example.
from abc import ABC, abstractmethod
class MyAbstractClass(ABC):
    @abstractmethod
    def abstract_method(self):
        pass
class MyConcreteClass(MyAbstractClass):
    def abstract_method(self):
        return "Implementation of the abstract method"
from abc import ABC, abstractmethod

# Define an abstract class with an abstract method
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

# Create concrete subclasses that implement the abstract method
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Instantiate objects and use the abstract interface
circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)

# Call the abstract method on concrete objects
print(f"Circle Area: {circle.calculate_area()}")
print(f"Rectangle Area: {rectangle.calculate_area()}")
# Out:
# Circle Area: 78.5
# Rectangle Area: 24

# %%
#5. How do abstract classes differ from regular classes in Python? Discuss their use cases.
#Abstract Class Example:
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass
#Regular Class Example:
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        return "Woof!"

# Instantiating a regular class
my_dog = Dog(name="Buddy")

# %%
#6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and providing methods to deposit and withdraw funds.
from abc import ABC, abstractmethod

class BankAccount(ABC):
    def __init__(self, account_holder, account_number):
        self.account_holder = account_holder
        self.account_number = account_number
        self._balance = 0  # Private attribute for balance

    @abstractmethod
    def display_balance(self):
        pass

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited ${amount}. New balance: ${self._balance}")
        else:
            print("Invalid deposit amount. Please deposit an amount greater than 0.")

    def withdraw(self, amount):
        if 0 < amount <= self._balance:
            self._balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self._balance}")
        else:
            print("Invalid withdrawal amount or insufficient funds.")

# Concrete subclass implementing the abstract method
class SavingsAccount(BankAccount):
    def display_balance(self):
        print(f"Savings Account Balance for {self.account_holder} ({self.account_number}): ${self._balance}")

# Example usage
savings_account = SavingsAccount(account_holder="John Doe", account_number="123456789")

# Depositing and displaying balance
savings_account.deposit(1000)
savings_account.display_balance()

# Withdrawing and displaying balance
savings_account.withdraw(500)
savings_account.display_balance()
# Out:
# Deposited $1000. New balance: $1000
# Savings Account Balance for John Doe (123456789): $1000
# Withdrew $500. New balance: $500
# Savings Account Balance for John Doe (123456789): $500

# %%
#7. Discuss the concept of interface classes in Python and their role in achieving abstraction.
'''Python doesn't have a native interface keyword like some other languages, 
the concept of interfaces is often
implemented using abstract classes with abstract methods or through informal agreements on method names.'''

from abc import ABC, abstractmethod

class Drawable(ABC):
    @abstractmethod
    def draw(self):
        pass

class Shape(Drawable):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def draw(self):
        print(f"Drawing a circle with radius {self.radius}")

    def area(self):
        return 3.14 * self.radius * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def draw(self):
        print(f"Drawing a square with side {self.side}")

    def area(self):
        return self.side * self.side

# %%
#8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class.
from abc import ABC, abstractmethod

class Animal(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def make_sound(self):
        pass

    @abstractmethod
    def eat(self):
        pass

    @abstractmethod
    def sleep(self):
        pass

class Mammal(Animal):
    @abstractmethod
    def give_birth(self):
        pass

class Bird(Animal):
    @abstractmethod
    def fly(self):
        pass

class Reptile(Animal):
    @abstractmethod
    def crawl(self):
        pass

class Lion(Mammal):
    def make_sound(self):
        return "Roar"

    def eat(self):
        return "Lion is eating meat"

    def sleep(self):
        return "Lion is sleeping"

    def give_birth(self):
        return "Lioness gave birth to cubs"

class Eagle(Bird):
    def make_sound(self):
        return "Screech"

    def eat(self):
        return "Eagle is eating fish"

    def sleep(self):
        return "Eagle is perched and sleeping"

    def fly(self):
        return "Eagle is flying high in the sky"

class Snake(Reptile):
    def make_sound(self):
        return "Hiss"

    def eat(self):
        return "Snake is swallowing its prey"

    def sleep(self):
        return "Snake is coiled up and resting"

    def crawl(self):
        return "Snake is slithering on the ground"

# Example usage
lion = Lion("Simba")
eagle = Eagle("Thunder")
snake = Snake("Slytherin")

animals = [lion, eagle, snake]

for animal in animals:
    print(f"{animal.name}: {animal.make_sound()}")
    print(f"{animal.name}: {animal.eat()}")
    print(f"{animal.name}: {animal.sleep()}")

    if isinstance(animal, Mammal):
        print(f"{animal.name}: {animal.give_birth()}")
    elif isinstance(animal, Bird):
        print(f"{animal.name}: {animal.fly()}")
    elif isinstance(animal, Reptile):
        print(f"{animal.name}: {animal.crawl()}")

    print("\n")
# Out:
# Simba: Roar
# Simba: Lion is eating meat
# Simba: Lion is sleeping
# Simba: Lioness gave birth to cubs
#
#
# Thunder: Screech
# Thunder: Eagle is eating fish
# Thunder: Eagle is perched and sleeping
# Thunder: Eagle is flying high in the sky
#
#
# Slytherin: Hiss
# Slytherin: Snake is swallowing its prey
# Slytherin: Snake is coiled up and resting
# Slytherin: Snake is slithering on the ground

# %%
#9. Explain the significance of encapsulation in achieving abstraction. Provide examples.
#Data Hiding:
class BankAccount:
    def __init__(self, account_holder, balance):
        self._account_holder = account_holder  # Encapsulated attribute
        self._balance = balance

    def get_balance(self):
        return self._balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self._balance:
            self._balance -= amount
#Access Control:
class Car:
    def __init__(self, make, model, year):
        self._make = make  # Protected attribute
        self._model = model
        self._year = year

    def start_engine(self):
        print("Engine started")

    def _internal_method(self):
        print("This method is for internal use only")

# %%
#10. What is the purpose of abstract methods, and how do they enforce abstraction in Python classes?
'''Abstract methods in Python serve the purpose of defining method 
signatures in an abstract base class (ABC) without providing an actual implementation.'''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def display_info(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

    def display_info(self):
        return f"Circle with radius {self.radius}"

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def display_info(self):
        return f"Rectangle with length {self.length} and width {self.width}"

# %%
#11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., `start()`, `stop()`) in an abstract base class.
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self._is_running = False  # Private attribute for running status

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

    def get_running_status(self):
        return self._is_running

class Car(Vehicle):
    def start(self):
        if not self._is_running:
            print(f"The {self.year} {self.make} {self.model} is starting.")
            self._is_running = True
        else:
            print("The car is already running.")

    def stop(self):
        if self._is_running:
            print(f"The {self.year} {self.make} {self.model} is stopping.")
            self._is_running = False
        else:
            print("The car is already stopped.")

class Motorcycle(Vehicle):
    def start(self):
        if not self._is_running:
            print(f"The {self.year} {self.make} {self.model} is revving up.")
            self._is_running = True
        else:
            print("The motorcycle is already running.")

    def stop(self):
        if self._is_running:
            print(f"The {self.year} {self.make} {self.model} is coming to a stop.")
            self._is_running = False
        else:
            print("The motorcycle is already stopped.")

# Example usage
car = Car(make="Toyota", model="Camry", year=2022)
motorcycle = Motorcycle(make="Harley-Davidson", model="Sportster", year=2021)

# Start and stop the car
car.start()
print(f"Is the car running? {car.get_running_status()}")
car.stop()
print(f"Is the car running? {car.get_running_status()}")

# Start and stop the motorcycle
motorcycle.start()
print(f"Is the motorcycle running? {motorcycle.get_running_status()}")
motorcycle.stop()
print(f"Is the motorcycle running? {motorcycle.get_running_status()}")
# Out:
# The 2022 Toyota Camry is starting.
# Is the car running? True
# The 2022 Toyota Camry is stopping.
# Is the car running? False
# The 2021 Harley-Davidson Sportster is revving up.
# Is the motorcycle running? True
# The 2021 Harley-Davidson Sportster is coming to a stop.
# Is the motorcycle running? False

# %%
#12. Describe the use of abstract properties in Python and how they can be employed in abstract classes.
from abc import ABC, abstractmethod
class MyAbstractClass(ABC):
    @property
    @abstractmethod
    def my_abstract_property(self):
        pass
class MyConcreteClass(MyAbstractClass):
    def __init__(self, value):
        self._my_property_value = value

    @property
    def my_abstract_property(self):
        return self._my_property_value
#example
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @property
    @abstractmethod
    def make(self):
        pass

    @property
    @abstractmethod
    def model(self):
        pass

class Car(Vehicle):
    def __init__(self, make, model):
        self._make = make
        self._model = model

    @property
    def make(self):
        return self._make

    @property
    def model(self):
        return self._model

# %%
#13. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement abstraction by defining a common `get_salary()` method.
from abc import ABC, abstractmethod

class Employee(ABC):
    def __init__(self, name, employee_id):
        self.name = name
        self.employee_id = employee_id

    @abstractmethod
    def get_salary(self):
        pass

    def display_info(self):
        return f"Employee ID: {self.employee_id}, Name: {self.name}"

class Manager(Employee):
    def __init__(self, name, employee_id, team_size):
        super().__init__(name, employee_id)
        self.team_size = team_size

    def get_salary(self):
        base_salary = 60000
        return base_salary + (self.team_size * 5000)

class Developer(Employee):
    def __init__(self, name, employee_id, programming_language):
        super().__init__(name, employee_id)
        self.programming_language = programming_language

    def get_salary(self):
        base_salary = 70000
        return base_salary + 2000  # Bonus for developers

class Designer(Employee):
    def __init__(self, name, employee_id, design_tool):
        super().__init__(name, employee_id)
        self.design_tool = design_tool

    def get_salary(self):
        base_salary = 65000
        return base_salary + 1000  # Bonus for designers

# Example usage
manager = Manager(name="John Doe", employee_id="M123", team_size=8)
developer = Developer(name="Alice Smith", employee_id="D456", programming_language="Python")
designer = Designer(name="Bob Johnson", employee_id="DS789", design_tool="Sketch")

employees = [manager, developer, designer]

for employee in employees:
    print(employee.display_info())
    print(f"Salary: ${employee.get_salary()}\n")
# Out:
# Employee ID: M123, Name: John Doe
# Salary: $100000
#
# Employee ID: D456, Name: Alice Smith
# Salary: $72000
#
# Employee ID: DS789, Name: Bob Johnson
# Salary: $66000

# %%
#14. Discuss the differences between abstract classes and concrete classes in Python, including their instantiation.
#Abstract Class Example:
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Instantiate concrete subclasses of the abstract class
circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)

# Call the method provided by the abstract class
print(f"Circle Area: {circle.calculate_area()}")
print(f"Rectangle Area: {rectangle.calculate_area()}")

#Concrete Class Example:
class Animal:
    def __init__(self, name, sound):
        self.name = name
        self.sound = sound

    def make_sound(self):
        return f"{self.name} says {self.sound}"

class Dog(Animal):
    def __init__(self, name):
        super().__init__(name, sound="Woof")

# Instantiate a concrete class
dog = Dog(name="Buddy")

# Call the method provided by the concrete class
print(dog.make_sound())
# Out:
# Circle Area: 78.5
# Rectangle Area: 24
# Buddy says Woof

# %%
#15. Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.
'''Abstract Data Types (ADTs) are high-level descriptions of data structures and the
operations that can be performed on them. They are abstract in the sense that they provide a conceptual model,
specifying the behavior of a data structure without specifying the implementation details.'''
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            raise IndexError("pop from an empty stack")

    def is_empty(self):
        return len(self.items) == 0

# Usage
stack = Stack()
stack.push(1)
stack.push(2)
stack.push(3)

while not stack.is_empty():
    print(stack.pop())
# Out:
# 3
# 2
# 1

# %%
#16. Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., `power_on()`, `shutdown()`) in an abstract base class.
from abc import ABC, abstractmethod

class ComputerSystem(ABC):
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.is_powered_on = False

    @abstractmethod
    def power_on(self):
        pass

    @abstractmethod
    def shutdown(self):
        pass

    def restart(self):
        if self.is_powered_on:
            print("Restarting the computer...")
            self.shutdown()
            self.power_on()
        else:
            print("Cannot restart. The computer is not powered on.")

class Desktop(ComputerSystem):
    def power_on(self):
        if not self.is_powered_on:
            print(f"Powering on the {self.brand} desktop ({self.model})...")
            self.is_powered_on = True
        else:
            print("The desktop is already powered on.")

    def shutdown(self):
        if self.is_powered_on:
            print("Shutting down the desktop...")
            self.is_powered_on = False
        else:
            print("The desktop is already powered off.")

class Laptop(ComputerSystem):
    def power_on(self):
        if not self.is_powered_on:
            print(f"Powering on the {self.brand} laptop ({self.model})...")
            self.is_powered_on = True
        else:
            print("The laptop is already powered on.")

    def shutdown(self):
        if self.is_powered_on:
            print("Shutting down the laptop...")
            self.is_powered_on = False
        else:
            print("The laptop is already powered off.")

# Example usage
desktop = Desktop(brand="Dell", model="OptiPlex")
laptop = Laptop(brand="HP", model="EliteBook")

# Power on and shutdown the computer systems
desktop.power_on()
desktop.shutdown()

laptop.power_on()
laptop.shutdown()

# Restart the computer systems
desktop.power_on()
desktop.restart()

laptop.power_on()
laptop.restart()
# Out:
# Powering on the Dell desktop (OptiPlex)...
# Shutting down the desktop...
# Powering on the HP laptop (EliteBook)...
# Shutting down the laptop...
# Powering on the Dell desktop (OptiPlex)...
# Restarting the computer...
# Shutting down the desktop...
# Powering on the Dell desktop (OptiPlex)...
# Powering on the HP laptop (EliteBook)...
# Restarting the computer...
# Shutting down the laptop...
# Powering on the HP laptop (EliteBook)...

# %%
#17. Discuss the benefits of using abstraction in large-scale software development projects.
'''Abstraction is a fundamental concept in software development that involves simplifying complex systems by hiding unnecessary details and exposing only relevant and essential features. When applied effectively, abstraction provides numerous benefits in large-scale software development projects:

Modularity and Code Organization:

Abstraction encourages the division of a system into modular components, each responsible for a specific aspect of functionality.
Modules with well-defined interfaces make it easier to organize and maintain code, facilitating collaboration among development teams.
Complexity Reduction:

Abstraction allows developers to focus on high-level concepts and ignore intricate implementation details, reducing the cognitive load.
By abstracting away complexity, developers can manage and understand large systems more effectively.
Code Reusability:

Abstracting common functionalities into reusable components promotes code reusability across different parts of the system.
Reusing abstracted components can lead to more efficient development, reduced duplication, and easier maintenance.
Ease of Maintenance and Updates:

Abstracting implementation details isolates changes to specific modules, reducing the impact of modifications on other parts of the system.
Maintenance becomes more straightforward, and updates can be applied without affecting the entire codebase.
Interoperability:

Well-defined abstractions facilitate interoperability between different components or systems.
Interfaces provide a common ground for integration, enabling the exchange of data and functionality between disparate parts of the software.
Parallel Development:

Abstraction allows different teams or developers to work on separate modules concurrently without extensive knowledge of each other's implementations.
Parallel development is more manageable as long as the interfaces are adhered to, ensuring compatibility.'''

# %%
#18. Explain how abstraction enhances code reusability and modularity in Python programs.
#Abstraction of Common Functionality:
# Example: Abstraction for a utility function
def perform_operation(a, b, operation):
    if operation == "add":
        return a + b
    elif operation == "multiply":
        return a * b
# Example: Abstraction with OOP
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"
# Example: Reusing the 'random' module for generating random numbers
import random

random_number = random.randint(1, 100)

# %%
#19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class.
from abc import ABC, abstractmethod

class LibrarySystem(ABC):
    def __init__(self, library_name):
        self.library_name = library_name
        self.books = {}

    @abstractmethod
    def add_book(self, book_title, author):
        pass

    @abstractmethod
    def borrow_book(self, book_title):
        pass

    def return_book(self, book_title):
        if book_title in self.books:
            print(f"Returning '{book_title}' to {self.library_name}.")
            self.books[book_title] += 1
        else:
            print(f"Book '{book_title}' not found in {self.library_name}.")

class PublicLibrary(LibrarySystem):
    def add_book(self, book_title, author):
        if book_title in self.books:
            self.books[book_title] += 1
        else:
            self.books[book_title] = 1
        print(f"Added '{book_title}' by {author} to {self.library_name}.")

    def borrow_book(self, book_title):
        if book_title in self.books and self.books[book_title] > 0:
            self.books[book_title] -= 1
            print(f"Borrowed '{book_title}' from {self.library_name}.")
        else:
            print(f"Book '{book_title}' is not available in {self.library_name}.")

class UniversityLibrary(LibrarySystem):
    def add_book(self, book_title, author):
        # University library may have a different book management system
        print(f"Added '{book_title}' by {author} to {self.library_name} with special processing.")

    def borrow_book(self, book_title):
        # University library may have a different borrowing process
        print(f"Borrowed '{book_title}' from {self.library_name} with special handling.")

# Example usage
public_library = PublicLibrary(library_name="City Public Library")
university_library = UniversityLibrary(library_name="University Central Library")

# Add and borrow books from the public library
public_library.add_book("The Great Gatsby", "F. Scott Fitzgerald")
public_library.borrow_book("The Great Gatsby")
public_library.return_book("The Great Gatsby")

# Add and borrow books from the university library
university_library.add_book("Introduction to Computer Science", "John Smith")
university_library.borrow_book("Introduction to Computer Science")
university_library.return_book("Introduction to Computer Science")
# Out:
# Added 'The Great Gatsby' by F. Scott Fitzgerald to City Public Library.
# Borrowed 'The Great Gatsby' from City Public Library.
# Returning 'The Great Gatsby' to City Public Library.
# Added 'Introduction to Computer Science' by John Smith to University Central Library with special processing.
# Borrowed 'Introduction to Computer Science' from University Central Library with special handling.
# Book 'Introduction to Computer Science' not found in University Central Library.

# %%
#20. Describe the concept of method abstraction in Python and how it relates to polymorphism.
from abc import ABC, abstractmethod

# Abstract base class defining the common interface
class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass

# Concrete classes implementing the common interface
class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

class Duck(Animal):
    def make_sound(self):
        return "Quack!"

# Function demonstrating polymorphism with the common interface
def animal_sound(animal):
    return animal.make_sound()

# Creating instances of different classes
dog = Dog()
cat = Cat()
duck = Duck()

# Demonstrating polymorphism
print(animal_sound(dog))  # Output: Woof!
print(animal_sound(cat))  # Output: Meow!
print(animal_sound(duck)) # Output: Quack!
# Out:
# Woof!
# Meow!
# Quack!

# %%
#Composition

# %%
#1. Explain the concept of composition in Python and how it is used to build complex objects from simpler ones.
'''Composition is a fundamental concept in object-oriented programming (OOP) that involves 
constructing complex objects by combining simpler objects. It allows you to create more modular 
and reusable code by building classes that are composed of other classes or objects, rather than
inheriting from them.Composition is an alternative to inheritance for creating relationships between classes.'''
class Engine:
    def start(self):
        return "Engine started"

class Wheels:
    def roll(self):
        return "Wheels rolling"

class Car:
    def __init__(self):
        # Composition: Car has an Engine and Wheels
        self.engine = Engine()
        self.wheels = Wheels()

    def start_car(self):
        return self.engine.start()

    def drive(self):
        return f"{self.wheels.roll()} and {self.start_car()}"

# Create a Car instance
my_car = Car()

# Use composition to perform actions
print(my_car.drive())  # Output: Wheels rolling and Engine started
# Out:
# Wheels rolling and Engine started

# %%
#2. Describe the difference between composition and inheritance in object-oriented programming.
#Composition: In composition, code reuse is achieved by including instances of other classes as attributes within a class. Each class encapsulates its own functionality, and the containing class delegates tasks to the contained classes.
class Engine:
    def start(self):
        return "Engine started"

class Wheels:
    def roll(self):
        return "Wheels rolling"

class Car:
    def __init__(self):
        # Composition: Car has an Engine and Wheels
        self.engine = Engine()
        self.wheels = Wheels()

    def start_car(self):
        return self.engine.start()

    def drive(self):
        return f"{self.wheels.roll()} and {self.start_car()}"

# Create a Car instance
my_car = Car()

# Use composition to perform actions
print(my_car.drive())  # Output: Wheels rolling and Engine started


#Inheritance: In inheritance, code reuse is achieved by creating a new class that is a modified version of an existing class. The new class inherits the attributes and methods of the existing class and may override or extend them.
class Vehicle:
    def start(self):
        return "Vehicle started"

    def stop(self):
        return "Vehicle stopped"

class Car(Vehicle):
    def drive(self):
        return f"{self.start()} and {self.stop()}"

# Create a Car instance
my_car = Car()

# Use inheritance to perform actions
print(my_car.drive())  # Output: Vehicle started and Vehicle stopped
# Out:
# Wheels rolling and Engine started
# Vehicle started and Vehicle stopped

# %%
#3. Create a Python class called `Author` with attributes for name and birthdate. Then, create a `Book` class that contains an instance of `Author` as a composition. Provide an example of creating a `Book` object.
class Author:
    def __init__(self, name, birthdate):
        self.name = name
        self.birthdate = birthdate

class Book:
    def __init__(self, title, author, publication_year):
        self.title = title
        self.author = author  # Composition: Book has an Author
        self.publication_year = publication_year

    def display_info(self):
        return f"{self.title} by {self.author.name}, published in {self.publication_year}"

# Create an Author instance
author_john_doe = Author("John Doe", "January 1, 1980")

# Create a Book instance with the Author instance as part of composition
book_example = Book("Example Book", author_john_doe, 2022)

# Display book information
print(book_example.display_info())
# Out:
# Example Book by John Doe, published in 2022

# %%
#4. Discuss the benefits of using composition over inheritance in Python, especially in terms of code flexibility and reusability.
'''
Flexibility:

Composition: With composition, you can easily change or replace components without affecting the overall structure of the class. This makes your code more adaptable to changes and allows for a more flexible design.
Inheritance: Inheritance can be less flexible because changes to the base class may impact all the derived classes. Modifications can affect the entire class hierarchy, making it less adaptable to changes.
Code Reusability:

Composition: Code reuse is achieved by combining instances of other classes as attributes within a class. Each class encapsulates its own functionality, promoting a modular and reusable codebase.
Inheritance: While inheritance supports code reuse, it can lead to a less modular code structure. Changes to the base class can affect all derived classes, potentially introducing unintended consequences.

Ease of Testing:

Composition: Classes with composition are often easier to test in isolation. Mocking or substituting components during testing can be simpler, as dependencies are usually injected through constructor parameters.
Inheritance: Inheritance hierarchies may require more effort in testing, as changes to the base class can affect multiple derived classes. Isolating specific parts for testing might be more challenging.
'''

# %%
#5. How can you implement composition in Python classes? Provide examples of using composition to create complex objects.
# Example 1: Composition in Python

class Engine:
    def start(self):
        return "Engine started"

class Wheels:
    def roll(self):
        return "Wheels rolling"

class Car:
    def __init__(self):
        # Composition: Car has an Engine and Wheels
        self.engine = Engine()
        self.wheels = Wheels()

    def start_car(self):
        return self.engine.start()

    def drive(self):
        return f"{self.wheels.roll()} and {self.start_car()}"

# Create a Car instance
my_car = Car()

# Use composition to perform actions
print(my_car.drive())  # Output: Wheels rolling and Engine started
# Out:
# Wheels rolling and Engine started

# %%
#6. Create a Python class hierarchy for a music player system, using composition to represent playlists and songs.
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration

    def play(self):
        return f"Playing: {self.title} by {self.artist}"

class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []

    def add_song(self, song):
        self.songs.append(song)

    def play_all(self):
        if not self.songs:
            return "Playlist is empty"
        else:
            playlist_info = f"Playing all songs in {self.name} playlist:\n"
            for song in self.songs:
                playlist_info += f"{song.play()}\n"
            return playlist_info

class MusicPlayer:
    def __init__(self):
        self.playlists = []

    def create_playlist(self, name):
        playlist = Playlist(name)
        self.playlists.append(playlist)
        return playlist

# Example usage:

# Create songs
song1 = Song("Song 1", "Artist 1", "3:30")
song2 = Song("Song 2", "Artist 2", "4:15")
song3 = Song("Song 3", "Artist 3", "2:50")

# Create a music player
music_player = MusicPlayer()

# Create playlists
playlist1 = music_player.create_playlist("My Favorites")
playlist2 = music_player.create_playlist("Rock Classics")

# Add songs to playlists
playlist1.add_song(song1)
playlist1.add_song(song2)
playlist2.add_song(song2)
playlist2.add_song(song3)

# Play songs
print(playlist1.play_all())
print(playlist2.play_all())
# Out:
# Playing all songs in My Favorites playlist:
# Playing: Song 1 by Artist 1
# Playing: Song 2 by Artist 2
#
# Playing all songs in Rock Classics playlist:
# Playing: Song 2 by Artist 2
# Playing: Song 3 by Artist 3

# %%
#7. Explain the concept of "has-a" relationships in composition and how it helps design software systems.
class Engine:
    def start(self):
        return "Engine started"

class Car:
    def __init__(self):
        # Composition: Car has an Engine
        self.engine = Engine()

    def start_car(self):
        return self.engine.start()

# Create a Car instance
my_car = Car()

# Use composition to perform actions
print(my_car.start_car())  # Output: Engine started
# Out:
# Engine started

# %%
#8. Create a Python class for a computer system, using composition to represent components like CPU, RAM, and storage devices.
class CPU:
    def __init__(self, model, cores):
        self.model = model
        self.cores = cores

    def process_data(self):
        return "Processing data using the CPU"

class RAM:
    def __init__(self, capacity):
        self.capacity = capacity

    def store_data(self):
        return "Storing data in RAM"

class StorageDevice:
    def __init__(self, capacity, storage_type):
        self.capacity = capacity
        self.storage_type = storage_type

    def read_data(self):
        return "Reading data from storage device"

class ComputerSystem:
    def __init__(self, cpu, ram, storage):
        # Composition: ComputerSystem has a CPU, RAM, and StorageDevice
        self.cpu = cpu
        self.ram = ram
        self.storage = storage

    def perform_computing_task(self):
        task_result = f"{self.cpu.process_data()}\n{self.ram.store_data()}\n{self.storage.read_data()}"
        return task_result

# Example usage:

# Create components
cpu_i7 = CPU("Intel Core i7", 4)
ram_16gb = RAM(16)
storage_ssd = StorageDevice(512, "SSD")

# Create a ComputerSystem instance with CPU, RAM, and StorageDevice as part of composition
my_computer = ComputerSystem(cpu_i7, ram_16gb, storage_ssd)

# Perform a computing task
result = my_computer.perform_computing_task()
print(result)
# Out:
# Processing data using the CPU
# Storing data in RAM
# Reading data from storage device

# %%
#9. Describe the concept of "delegation" in composition and how it simplifies the design of complex systems.
'''
Delegation, in the context of composition, refers to the practice of one class (or object) assigning
a responsibility or task to another class, typically through the use of composition. In other words, 
rather than implementing the functionality directly,
a class delegates the task to an instance of another class that is part of its composition.'''
class Scheduler:
    def schedule_task(self, task):
        return f"Scheduling task: {task}"

class ProjectManager:
    def __init__(self, scheduler):
        # Delegation: ProjectManager delegates scheduling to a Scheduler
        self.scheduler = scheduler

    def assign_task(self, task):
        return self.scheduler.schedule_task(task)

# Example usage:

# Create a Scheduler instance
task_scheduler = Scheduler()

# Create a ProjectManager instance with a Scheduler as part of composition
project_manager = ProjectManager(task_scheduler)

# Delegate the task of scheduling to the Scheduler
result = project_manager.assign_task("Complete project documentation")
print(result)
# Out:
# Scheduling task: Complete project documentation

# %%
#10. Create a Python class for a car, using composition to represent components like the engine, wheels, and transmission.
class Engine:
    def start(self):
        return "Engine started"

    def stop(self):
        return "Engine stopped"

class Wheels:
    def accelerate(self):
        return "Wheels accelerating"

    def brake(self):
        return "Wheels braking"

class Transmission:
    def shift_gear(self):
        return "Gear shifted"

class Car:
    def __init__(self, engine, wheels, transmission):
        # Composition: Car has an Engine, Wheels, and Transmission
        self.engine = engine
        self.wheels = wheels
        self.transmission = transmission

    def start_car(self):
        return self.engine.start()

    def drive(self):
        return f"{self.wheels.accelerate()} and {self.transmission.shift_gear()}"

    def stop_car(self):
        return self.engine.stop()

# Example usage:

# Create components
car_engine = Engine()
car_wheels = Wheels()
car_transmission = Transmission()

# Create a Car instance with Engine, Wheels, and Transmission as part of composition
my_car = Car(car_engine, car_wheels, car_transmission)

# Perform car actions
print(my_car.start_car())  # Output: Engine started
print(my_car.drive())      # Output: Wheels accelerating and Gear shifted
print(my_car.stop_car())   # Output: Engine stopped
# Out:
# Engine started
# Wheels accelerating and Gear shifted
# Engine stopped

# %%
#11. How can you encapsulate and hide the details of composed objects in Python classes to maintain abstraction?
#Private Attributes and Methods:
class Car:
    def __init__(self, engine, wheels, transmission):
        self.__engine = engine
        self.__wheels = wheels
        self.__transmission = transmission

    def start_car(self):
        return self.__engine.start()

    def drive(self):
        return f"{self.__wheels.accelerate()} and {self.__transmission.shift_gear()}"

    def stop_car(self):
        return self.__engine.stop()
#Getter and Setter Methods:
class Car:
    def __init__(self, engine, wheels, transmission):
        self.__engine = engine
        self.__wheels = wheels
        self.__transmission = transmission

    def get_engine(self):
        return self.__engine

    def set_engine(self, engine):
        # Add validation logic if needed
        self.__engine = engine

    # Similarly, provide getter and setter methods for other components

# %%
#12. Create a Python class for a university course, using composition to represent students, instructors, and course materials.
class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name

    def enroll(self, course):
        return f"{self.name} has enrolled in {course.title}"

class Instructor:
    def __init__(self, instructor_id, name):
        self.instructor_id = instructor_id
        self.name = name

    def assign_grade(self, student, course, grade):
        return f"{self.name} assigned a grade of {grade} to {student.name} for {course.title}"

class CourseMaterial:
    def __init__(self, title, content):
        self.title = title
        self.content = content

class UniversityCourse:
    def __init__(self, title, instructor, students, course_material):
        # Composition: UniversityCourse has an Instructor, Students, and CourseMaterial
        self.title = title
        self.instructor = instructor
        self.students = students
        self.course_material = course_material

    def display_course_info(self):
        info = f"Course: {self.title}\nInstructor: {self.instructor.name}\n"
        info += "Students:\n"
        for student in self.students:
            info += f"- {student.name}\n"
        info += f"Course Material: {self.course_material.title}"
        return info

# Example usage:

# Create students
student1 = Student(1, "Alice")
student2 = Student(2, "Bob")

# Create an instructor
instructor = Instructor(101, "Professor Smith")

# Create course material
material = CourseMaterial("Introduction to Python", "Course content goes here...")

# Create a UniversityCourse instance with Instructor, Students, and CourseMaterial as part of composition
python_course = UniversityCourse("Python Programming", instructor, [student1, student2], material)

# Enroll students in the course
enrollment_results = [student.enroll(python_course) for student in [student1, student2]]

# Display course information
course_info = python_course.display_course_info()

# Assign grades
grades = [instructor.assign_grade(student, python_course, "A") for student in [student1, student2]]

# Print results
print("Enrollment Results:")
print("\n".join(enrollment_results))
print("\nCourse Information:")
print(course_info)
print("\nGrade Assignments:")
print("\n".join(grades))
# Out:
# Enrollment Results:
# Alice has enrolled in Python Programming
# Bob has enrolled in Python Programming
#
# Course Information:
# Course: Python Programming
# Instructor: Professor Smith
# Students:
# - Alice
# - Bob
# Course Material: Introduction to Python
#
# Grade Assignments:
# Professor Smith assigned a grade of A to Alice for Python Programming
# Professor Smith assigned a grade of A to Bob for Python Programming

# %%
#13. Discuss the challenges and drawbacks of composition, such as increased complexity and potential for tight coupling between objects.
'''
While composition is a powerful design concept, it also comes with challenges and potential drawbacks that developers should be aware of. Here are some of the challenges and drawbacks associated with composition:

Increased Complexity:

As a system grows, the number of composed objects and their interactions may increase, leading to a more complex codebase. Managing relationships and dependencies between components can become challenging, especially in large projects.
Potential for Tight Coupling:

If not carefully managed, composition can lead to tight coupling between objects. Tight coupling occurs when the internal details of one object are dependent on the internal details of another object. This makes it difficult to modify one object without affecting others.
Dependency Management:

Managing dependencies between objects becomes crucial in a composed system. Changes to one object may have a ripple effect on other dependent objects, requiring careful consideration of the impact of modifications.
Constructor Overhead:

In languages that lack support for default values in constructors, the need to pass instances of composed objects through the constructor can lead to increased constructor overhead and more verbose instantiation.'''

# %%
#14. Create a Python class hierarchy for a restaurant system, using composition to represent menus, dishes, and ingredients.
class Ingredient:
    def __init__(self, name, quantity):
        self.name = name
        self.quantity = quantity

    def __str__(self):
        return f"{self.quantity} units of {self.name}"

class Dish:
    def __init__(self, name, ingredients):
        self.name = name
        self.ingredients = ingredients

    def display_dish(self):
        info = f"Dish: {self.name}\nIngredients:\n"
        for ingredient in self.ingredients:
            info += f"- {ingredient}\n"
        return info

class Menu:
    def __init__(self, name, dishes):
        # Composition: Menu has Dishes
        self.name = name
        self.dishes = dishes

    def display_menu(self):
        info = f"Menu: {self.name}\nDishes:\n"
        for dish in self.dishes:
            info += f"{dish.display_dish()}\n"
        return info

# Example usage:

# Create ingredients
ingredient1 = Ingredient("Tomato", 3)
ingredient2 = Ingredient("Cheese", 200)
ingredient3 = Ingredient("Dough", 1)

# Create dishes
pizza = Dish("Margherita Pizza", [ingredient1, ingredient2, ingredient3])
pasta = Dish("Spaghetti Bolognese", [ingredient1, ingredient2])

# Create a menu with dishes as part of composition
italian_menu = Menu("Italian Menu", [pizza, pasta])

# Display menu information
menu_info = italian_menu.display_menu()
print(menu_info)
# Out:
# Menu: Italian Menu
# Dishes:
# Dish: Margherita Pizza
# Ingredients:
# - 3 units of Tomato
# - 200 units of Cheese
# - 1 units of Dough
#
# Dish: Spaghetti Bolognese
# Ingredients:
# - 3 units of Tomato
# - 200 units of Cheese

# %%
#15. Explain how composition enhances code maintainability and modularity in Python programs.
'''
Composition enhances code maintainability and modularity in Python programs by promoting a more flexible and modular design. Here are some ways in which composition achieves these benefits:

Separation of Concerns:

Composition allows you to break down a system into smaller, more manageable components, each responsible for a specific concern. This separation of concerns makes it easier to understand, modify, and maintain individual parts of the codebase.
Modularity:

With composition, each class represents a module or component with a well-defined set of responsibilities. These modules can be developed, tested, and maintained independently, promoting a modular and scalable architecture.
Code Reusability:

Composition facilitates code reusability by allowing you to reuse existing classes or components in different contexts. Instead of inheriting behavior, you can compose classes, promoting a "has-a" relationship that is more flexible and less prone to issues like the diamond problem in multiple inheritance.
Flexibility and Adaptability:

Components in a composed system can be easily replaced or extended without affecting the overall structure. This flexibility is essential for adapting to changing requirements or introducing new features without rewriting large portions of the code.
Encapsulation:

Composition supports encapsulation, where each class encapsulates its own implementation details. This encapsulation helps in hiding the internal complexities of a component, allowing for changes to be made within the class without impacting other parts of the system.
Reduced Code Coupling:

Composition helps in reducing tight coupling between objects. Objects interact through well-defined interfaces, and changes to one object don't necessarily affect others. This reduces the likelihood of unintended side effects when modifying the code.
Easier Testing:

Testing individual components in isolation is often easier with composition. Mocking or substituting components during testing can be done more effectively, as dependencies are usually injected through constructor parameters, making it easier to create test doubles.'''

class Engine:
    def start(self):
        return "Engine started"

    def stop(self):
        return "Engine stopped"

class Wheels:
    def accelerate(self):
        return "Wheels accelerating"

    def brake(self):
        return "Wheels braking"

class Transmission:
    def shift_gear(self):
        return "Gear shifted"

class Car:
    def __init__(self, engine, wheels, transmission):
        # Composition: Car has an Engine, Wheels, and Transmission
        self.engine = engine
        self.wheels = wheels
        self.transmission = transmission

    def start_car(self):
        return self.engine.start()

    def drive(self):
        return f"{self.wheels.accelerate()} and {self.transmission.shift_gear()}"

    def stop_car(self):
        return self.engine.stop()

# Example usage:

# Create components
car_engine = Engine()
car_wheels = Wheels()
car_transmission = Transmission()

# Create a Car instance with Engine, Wheels, and Transmission as part of composition
my_car = Car(car_engine, car_wheels, car_transmission)

# Perform car actions
print(my_car.start_car())  # Output: Engine started
print(my_car.drive())      # Output: Wheels accelerating and Gear shifted
print(my_car.stop_car())   # Output: Engine stopped
# Out:
# Engine started
# Wheels accelerating and Gear shifted
# Engine stopped

# %%
#16. Create a Python class for a computer game character, using composition to represent attributes like weapons, armor, and inventory.
class Weapon:
    def __init__(self, name, damage):
        self.name = name
        self.damage = damage

    def attack(self):
        return f"Attacking with {self.name}, dealing {self.damage} damage"

class Armor:
    def __init__(self, name, defense):
        self.name = name
        self.defense = defense

    def absorb_damage(self, damage):
        absorbed_damage = min(damage, self.defense)
        self.defense -= absorbed_damage
        return f"{self.name} absorbed {absorbed_damage} damage"

class Inventory:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

    def view_inventory(self):
        return f"Inventory: {', '.join(item.name for item in self.items)}"

class GameCharacter:
    def __init__(self, name, health, weapon=None, armor=None, inventory=None):
        self.name = name
        self.health = health
        # Composition: GameCharacter has Weapon, Armor, and Inventory
        self.weapon = weapon
        self.armor = armor
        self.inventory = inventory or Inventory()

    def equip_weapon(self, weapon):
        self.weapon = weapon

    def equip_armor(self, armor):
        self.armor = armor

    def take_damage(self, damage):
        if self.armor:
            damage_message = self.armor.absorb_damage(damage)
            damage -= damage - self.armor.defense
        else:
            damage_message = f"{self.name} took {damage} damage"

        self.health -= damage
        return f"{self.name} has {self.health} health remaining. {damage_message}"

    def use_weapon(self, target):
        if self.weapon:
            return f"{self.name} attacks {target.name}. {self.weapon.attack()}"
        else:
            return f"{self.name} has no weapon equipped."

# Example usage:

# Create items
sword = Weapon("Sword", 20)
shield = Armor("Shield", 15)

# Create a GameCharacter instance with Weapon, Armor, and Inventory as part of composition
hero = GameCharacter("Hero", 100, weapon=sword, armor=shield)

# Create another GameCharacter
enemy = GameCharacter("Enemy", 50)

# Attack using the equipped weapon
attack_result = hero.use_weapon(enemy)
print(attack_result)

# Enemy takes damage
damage_result = enemy.take_damage(25)
print(damage_result)

# View hero's inventory
hero.inventory.add_item(sword)
hero.inventory.add_item(shield)
print(hero.inventory.view_inventory())
# Out:
# Hero attacks Enemy. Attacking with Sword, dealing 20 damage
# Enemy has 25 health remaining. Enemy took 25 damage
# Inventory: Sword, Shield

# %%
#17. Describe the concept of "aggregation" in composition and how it differs from simple composition.
'''Aggregation is a specific form of composition in object-oriented programming where one class 
represents a "whole" or "container," and another class represents a "part" or "component." 
In aggregation, the "whole" class maintains a relationship with the "part" class, but the "part"
class remains independent and can exist outside the context of the "whole" class.'''
class Professor:
    def __init__(self, name):
        self.name = name

class Department:
    def __init__(self, name, professors=[]):
        self.name = name
        # Aggregation: Department aggregates Professor objects
        self.professors = professors

# Example usage
prof1 = Professor("Dr. Smith")
prof2 = Professor("Dr. Johnson")

# Aggregation: Creating a department with professors
computer_science = Department("Computer Science", professors=[prof1, prof2])

# Professors can still exist independently
print(prof1.name)  # Output: Dr. Smith
# Out:
# Dr. Smith

# %%
#18. Create a Python class for a house, using composition to represent rooms, furniture, and appliances.
class Furniture:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"{self.name}"

class Appliance:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"{self.name}"

class Room:
    def __init__(self, name, furniture=None, appliances=None):
        self.name = name
        # Composition: Room has Furniture and Appliances
        self.furniture = furniture or []
        self.appliances = appliances or []

    def add_furniture(self, furniture):
        self.furniture.append(furniture)

    def add_appliance(self, appliance):
        self.appliances.append(appliance)

    def describe_room(self):
        furniture_list = ', '.join(str(item) for item in self.furniture)
        appliance_list = ', '.join(str(item) for item in self.appliances)

        return f"{self.name} has the following:\nFurniture: {furniture_list}\nAppliances: {appliance_list}"

class House:
    def __init__(self, rooms=None):
        # Composition: House has Rooms
        self.rooms = rooms or []

    def add_room(self, room):
        self.rooms.append(room)

    def describe_house(self):
        room_descriptions = [room.describe_room() for room in self.rooms]
        return '\n'.join(room_descriptions)

# Example usage:

# Create furniture and appliances
sofa = Furniture("Sofa")
table = Furniture("Coffee Table")
oven = Appliance("Oven")
tv = Appliance("TV")

# Create rooms with furniture and appliances as part of composition
living_room = Room("Living Room", furniture=[sofa, table], appliances=[tv])
kitchen = Room("Kitchen", appliances=[oven])

# Create a house with rooms as part of composition
my_house = House(rooms=[living_room, kitchen])

# Add more rooms to the house
bedroom = Room("Bedroom", furniture=[Furniture("Bed"), Furniture("Wardrobe")])
my_house.add_room(bedroom)

# Describe the house
print(my_house.describe_house())
# Out:
# Living Room has the following:
# Furniture: Sofa, Coffee Table
# Appliances: TV
# Kitchen has the following:
# Furniture:
# Appliances: Oven
# Bedroom has the following:
# Furniture: Bed, Wardrobe
# Appliances:

# %%
#19. How can you achieve flexibility in composed objects by allowing them to be replaced or modified dynamically at runtime?
#Interfaces and Abstract Classes:
from abc import ABC, abstractmethod

class Component(ABC):
    @abstractmethod
    def operation(self):
        pass

# %%
#20. Create a Python class for a social media application, using composition to represent users, posts, and comments.
